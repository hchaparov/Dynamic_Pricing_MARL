# %% [markdown]
# <a href="https://colab.research.google.com/github/hchaparov/Dynamic_Pricing_MARL/blob/main/Final_SA_PONG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# !pip install ffmpeg
# !pip install swig
# Out:
# Requirement already satisfied: stable-baselines3[extra]>=2.0.0a4 in /usr/local/lib/python3.10/dist-packages (2.4.0a4)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (0.29.1)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (1.25.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.3.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.8.0.76)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.15.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.66.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (13.7.1)
# Requirement already satisfied: shimmy[atari]~=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (9.4.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (0.6.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a4) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a4) (0.0.4)
# Requirement already satisfied: ale-py~=0.8.1 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=1.3.0->stable-baselines3[extra]>=2.0.0a4) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (12.5.82)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]>=2.0.0a4) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]>=2.0.0a4) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0->stable-baselines3[extra]>=2.0.0a4) (6.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.2.2)
# Requirement already satisfied: ffmpeg in /usr/local/lib/python3.10/dist-packages (1.4)
# Requirement already satisfied: swig in /usr/local/lib/python3.10/dist-packages (4.2.1)

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import sys
import inspect
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import HTML
from base64 import b64encode

import gymnasium as gym

from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.env_util import make_atari_env, make_vec_env
from stable_baselines3.common.vec_env import VecFrameStack, VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.monitor import Monitor, load_results
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback, BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.results_plotter import load_results, ts2xy

import torch as th
import torch.nn as nn
th.set_printoptions(profile="full")

from tqdm.auto import tqdm
# Out:
# Mounted at /content/drive

# %%
ENV_ID = "PongNoFrameskip-v4"
n_training_envs = 8

# Directories for logging purposes
LOG_DIR_PPO = "/content/drive/My Drive/SA_PongNoFrameskip_all_test/PPO"
os.makedirs(LOG_DIR_PPO, exist_ok=True)

LOG_DIR_PPO_EV = "/content/drive/My Drive/SA_PongNoFrameskip_all_test/PPO_eval"
os.makedirs(LOG_DIR_PPO_EV, exist_ok=True)

LOG_DIR_A2C = "/content/drive/My Drive/SA_PongNoFrameskip_all_test/A2C"
os.makedirs(LOG_DIR_A2C, exist_ok=True)

LOG_DIR_A2C_EV = "/content/drive/My Drive/SA_PongNoFrameskip_all_test/A2C_eval"
os.makedirs(LOG_DIR_A2C_EV, exist_ok=True)

LOG_DIR_DQN = "/content/drive/My Drive/SA_PongNoFrameskip_all_test/DQN"
os.makedirs(LOG_DIR_DQN, exist_ok=True)

LOG_DIR_DQN_EV = "/content/drive/My Drive/SA_PongNoFrameskip_all_test/DQN_eval"
os.makedirs(LOG_DIR_DQN_EV, exist_ok=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Initialize a vectorized training environment with default parameters
train_env_ppo = make_atari_env(ENV_ID, n_envs=n_training_envs, monitor_dir=LOG_DIR_PPO, seed=0)

eval_env_ppo = make_atari_env(ENV_ID, n_envs=n_training_envs, monitor_dir=LOG_DIR_PPO_EV, seed=0)

train_env_a2c = make_atari_env(ENV_ID, n_envs=n_training_envs, monitor_dir=LOG_DIR_A2C, seed=0)

eval_env_a2c = make_atari_env(ENV_ID, n_envs=n_training_envs, monitor_dir=LOG_DIR_A2C_EV, seed=0)

train_env_dqn = make_atari_env(ENV_ID, n_envs=n_training_envs, monitor_dir=LOG_DIR_DQN, seed=0)

eval_env_dqn = make_atari_env(ENV_ID, n_envs=n_training_envs, monitor_dir=LOG_DIR_DQN_EV, seed=0)

# %%
# Initialize periodical evaluation of the model's performance
def eval_callback(eval_env, log_dir_ev):
  EVAL_FREQ = 8192 # The policy is updated every 8196 timesteps
  EVAL_EPISODES = 16 # How many episodes the agent should be tested for evaluation

  eval_callback_z = EvalCallback(
                    eval_env = eval_env,
                    n_eval_episodes = EVAL_EPISODES,
                    best_model_save_path = log_dir_ev,
                    log_path = log_dir_ev,
                    eval_freq = EVAL_FREQ,
                    deterministic = True,
                    render = False
                )
  return eval_callback_z

# %%
MODEL_PATH_PPO = "/content/drive/My Drive/SA_PongNoFrameskip_all_test/PPO/model_10mil"
MODEL_PATH_A2C = "/content/drive/My Drive/SA_PongNoFrameskip_all_test/A2C/model_10mil"
MODEL_PATH_DQN = "/content/drive/My Drive/SA_PongNoFrameskip_all_test/DQN/model_10mil"

TOTAL_TIMESTEPS = 10000000

# Initialize PPO model
model_ppo = PPO(policy = "CnnPolicy",
            env = train_env_ppo,
            batch_size = 256,
            clip_range = 0.1,
            ent_coef = 0.01,
            gae_lambda = 0.9,
            gamma = 0.99,
            learning_rate = 0.00025,
            max_grad_norm = 0.5,
            n_epochs = 4,
            n_steps = 128,
            vf_coef = 0.5,
            verbose=1
            )


eval_callback_ppo = eval_callback(eval_env=eval_env_ppo, log_dir_ev=LOG_DIR_PPO_EV)


# Initialize A2C model
model_a2c = A2C(policy = "CnnPolicy",
            env = train_env_a2c,
            ent_coef = 0.01,
            gamma = 0.99,
            learning_rate = 0.00025,
            max_grad_norm = 0.5,
            n_steps = 128,
            vf_coef = 0.25,
            verbose = 1
            )

eval_callback_a2c = eval_callback(eval_env=eval_env_a2c, log_dir_ev=LOG_DIR_A2C_EV)


# Initialize DQN model
model_dqn = DQN(policy = 'CnnPolicy',
            env=train_env_dqn,
            learning_rate=0.0001,
            buffer_size=100000,
            learning_starts=1000,
            batch_size=32,
            tau=1.0,
            gamma=0.99,
            train_freq=(4, 'step'),
            gradient_steps=1,
            target_update_interval=500,
            exploration_initial_eps=1.0,
            exploration_final_eps=0.05,
            exploration_fraction=0.1,
            verbose=1,
            )

eval_callback_dqn = eval_callback(eval_env=eval_env_dqn, log_dir_ev=LOG_DIR_DQN_EV)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
# Train the A2C agent
agent_a2c = model_a2c.learn(total_timesteps = TOTAL_TIMESTEPS, callback =  eval_callback_a2c)
agent_a2c.save(MODEL_PATH_A2C)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7f46bc9ea170> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f46e6bf9bd0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# Eval num_timesteps=65536, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 65536    |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.00337  |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 63       |
# |    policy_loss        | -0.201   |
# |    value_loss         | 0.251    |
# ------------------------------------
# New best mean reward!
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.64e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 651      |
# |    iterations         | 100      |
# |    time_elapsed       | 157      |
# |    total_timesteps    | 102400   |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.0114   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 99       |
# |    policy_loss        | 0.271    |
# |    value_loss         | 0.311    |
# ------------------------------------
# Eval num_timesteps=131072, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 131072   |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.00689  |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 127      |
# |    policy_loss        | -0.438   |
# |    value_loss         | 0.271    |
# ------------------------------------
# Eval num_timesteps=196608, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 196608   |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.0201   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 191      |
# |    policy_loss        | -0.0302  |
# |    value_loss         | 0.475    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 637      |
# |    iterations         | 200      |
# |    time_elapsed       | 321      |
# |    total_timesteps    | 204800   |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.00821  |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 199      |
# |    policy_loss        | 0.318    |
# |    value_loss         | 0.542    |
# ------------------------------------
# Eval num_timesteps=262144, episode_reward=-21.00 +/- 0.00
# Episode length: 3102.81 +/- 62.94
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.1e+03  |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 262144   |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.0249   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 255      |
# |    policy_loss        | 0.338    |
# |    value_loss         | 0.345    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.76e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 653      |
# |    iterations         | 300      |
# |    time_elapsed       | 470      |
# |    total_timesteps    | 307200   |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | -0.00031 |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 299      |
# |    policy_loss        | 0.298    |
# |    value_loss         | 0.274    |
# ------------------------------------
# Eval num_timesteps=327680, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 327680   |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.0531   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 319      |
# |    policy_loss        | 0.102    |
# |    value_loss         | 0.439    |
# ------------------------------------
# Eval num_timesteps=393216, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 393216   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.0948   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 383      |
# |    policy_loss        | 0.501    |
# |    value_loss         | 0.504    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.78e+03 |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 646      |
# |    iterations         | 400      |
# |    time_elapsed       | 633      |
# |    total_timesteps    | 409600   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.0148   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 399      |
# |    policy_loss        | -0.184   |
# |    value_loss         | 0.501    |
# ------------------------------------
# Eval num_timesteps=458752, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 458752   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.185    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 447      |
# |    policy_loss        | 0.372    |
# |    value_loss         | 0.263    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.78e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 649      |
# |    iterations         | 500      |
# |    time_elapsed       | 787      |
# |    total_timesteps    | 512000   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.182    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 499      |
# |    policy_loss        | -0.399   |
# |    value_loss         | 0.249    |
# ------------------------------------
# Eval num_timesteps=524288, episode_reward=-21.00 +/- 0.00
# Episode length: 5156.00 +/- 2381.18
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 5.16e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 524288   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.0558   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 511      |
# |    policy_loss        | -0.577   |
# |    value_loss         | 0.302    |
# ------------------------------------
# Eval num_timesteps=589824, episode_reward=-21.00 +/- 0.00
# Episode length: 3086.00 +/- 79.37
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.09e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 589824   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.195    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 575      |
# |    policy_loss        | -0.0229  |
# |    value_loss         | 0.315    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.76e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 634      |
# |    iterations         | 600      |
# |    time_elapsed       | 969      |
# |    total_timesteps    | 614400   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.202    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 599      |
# |    policy_loss        | 0.291    |
# |    value_loss         | 0.325    |
# ------------------------------------
# Eval num_timesteps=655360, episode_reward=-20.94 +/- 0.24
# Episode length: 3074.25 +/- 70.68
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.07e+03 |
# |    mean_reward        | -20.9    |
# | time/                 |          |
# |    total_timesteps    | 655360   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.0513   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 639      |
# |    policy_loss        | -0.51    |
# |    value_loss         | 0.219    |
# ------------------------------------
# New best mean reward!
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.78e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 638      |
# |    iterations         | 700      |
# |    time_elapsed       | 1123     |
# |    total_timesteps    | 716800   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.0936   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 699      |
# |    policy_loss        | 0.176    |
# |    value_loss         | 0.391    |
# ------------------------------------
# Eval num_timesteps=720896, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 720896   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.268    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 703      |
# |    policy_loss        | 0.484    |
# |    value_loss         | 0.47     |
# ------------------------------------
# Eval num_timesteps=786432, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 786432   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.343    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 767      |
# |    policy_loss        | -0.465   |
# |    value_loss         | 0.213    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.76e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 632      |
# |    iterations         | 800      |
# |    time_elapsed       | 1295     |
# |    total_timesteps    | 819200   |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.463    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 799      |
# |    policy_loss        | 0.333    |
# |    value_loss         | 0.287    |
# ------------------------------------
# Eval num_timesteps=851968, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 851968   |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.123    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 831      |
# |    policy_loss        | 0.245    |
# |    value_loss         | 0.182    |
# ------------------------------------
# Eval num_timesteps=917504, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 917504   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.481    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 895      |
# |    policy_loss        | -0.343   |
# |    value_loss         | 0.165    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.72e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 631      |
# |    iterations         | 900      |
# |    time_elapsed       | 1460     |
# |    total_timesteps    | 921600   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.0322   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 899      |
# |    policy_loss        | -0.36    |
# |    value_loss         | 0.375    |
# ------------------------------------
# Eval num_timesteps=983040, episode_reward=-20.94 +/- 0.24
# Episode length: 3080.12 +/- 76.25
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.08e+03 |
# |    mean_reward        | -20.9    |
# | time/                 |          |
# |    total_timesteps    | 983040   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.455    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 959      |
# |    policy_loss        | -0.547   |
# |    value_loss         | 0.237    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.7e+03  |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 635      |
# |    iterations         | 1000     |
# |    time_elapsed       | 1611     |
# |    total_timesteps    | 1024000  |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.501    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 999      |
# |    policy_loss        | -0.271   |
# |    value_loss         | 0.142    |
# ------------------------------------
# Eval num_timesteps=1048576, episode_reward=-21.00 +/- 0.00
# Episode length: 3122.06 +/- 87.08
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.12e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1048576  |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.11     |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1023     |
# |    policy_loss        | -0.313   |
# |    value_loss         | 0.317    |
# ------------------------------------
# Eval num_timesteps=1114112, episode_reward=-21.00 +/- 0.00
# Episode length: 3067.81 +/- 45.75
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.07e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1114112  |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.339    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1087     |
# |    policy_loss        | -0.142   |
# |    value_loss         | 0.193    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.8e+03  |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 635      |
# |    iterations         | 1100     |
# |    time_elapsed       | 1771     |
# |    total_timesteps    | 1126400  |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.583    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.188   |
# |    value_loss         | 0.284    |
# ------------------------------------
# Eval num_timesteps=1179648, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1179648  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.14     |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1151     |
# |    policy_loss        | -0.453   |
# |    value_loss         | 0.263    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.82e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 641      |
# |    iterations         | 1200     |
# |    time_elapsed       | 1916     |
# |    total_timesteps    | 1228800  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.258    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.345   |
# |    value_loss         | 0.227    |
# ------------------------------------
# Eval num_timesteps=1245184, episode_reward=-21.00 +/- 0.00
# Episode length: 3071.50 +/- 60.03
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.07e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1245184  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.289    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1215     |
# |    policy_loss        | -0.309   |
# |    value_loss         | 0.219    |
# ------------------------------------
# Eval num_timesteps=1310720, episode_reward=-20.88 +/- 0.33
# Episode length: 3134.88 +/- 225.81
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.13e+03 |
# |    mean_reward        | -20.9    |
# | time/                 |          |
# |    total_timesteps    | 1310720  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.202    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1279     |
# |    policy_loss        | -0.184   |
# |    value_loss         | 0.207    |
# ------------------------------------
# New best mean reward!
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.82e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 640      |
# |    iterations         | 1300     |
# |    time_elapsed       | 2078     |
# |    total_timesteps    | 1331200  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.208    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.42     |
# |    value_loss         | 0.435    |
# ------------------------------------
# Eval num_timesteps=1376256, episode_reward=-21.00 +/- 0.00
# Episode length: 3086.75 +/- 81.36
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.09e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1376256  |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.516    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1343     |
# |    policy_loss        | -0.0141  |
# |    value_loss         | 0.176    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.68e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 644      |
# |    iterations         | 1400     |
# |    time_elapsed       | 2224     |
# |    total_timesteps    | 1433600  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.366    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.177    |
# |    value_loss         | 0.146    |
# ------------------------------------
# Eval num_timesteps=1441792, episode_reward=-21.00 +/- 0.00
# Episode length: 3071.50 +/- 60.03
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.07e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1441792  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.419    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1407     |
# |    policy_loss        | 0.32     |
# |    value_loss         | 0.287    |
# ------------------------------------
# Eval num_timesteps=1507328, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1507328  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.455    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1471     |
# |    policy_loss        | -0.0726  |
# |    value_loss         | 0.209    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.77e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 644      |
# |    iterations         | 1500     |
# |    time_elapsed       | 2383     |
# |    total_timesteps    | 1536000  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.149    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.672    |
# |    value_loss         | 0.727    |
# ------------------------------------
# Eval num_timesteps=1572864, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1572864  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.553    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1535     |
# |    policy_loss        | -0.289   |
# |    value_loss         | 0.168    |
# ------------------------------------
# Eval num_timesteps=1638400, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1638400  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.226    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.324    |
# |    value_loss         | 0.359    |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.76e+03 |
# |    ep_rew_mean     | -20.3    |
# | time/              |          |
# |    fps             | 644      |
# |    iterations      | 1600     |
# |    time_elapsed    | 2541     |
# |    total_timesteps | 1638400  |
# ---------------------------------
# Eval num_timesteps=1703936, episode_reward=-21.00 +/- 0.00
# Episode length: 3071.25 +/- 59.06
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.07e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1703936  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.271    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1663     |
# |    policy_loss        | 0.727    |
# |    value_loss         | 0.336    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.79e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 647      |
# |    iterations         | 1700     |
# |    time_elapsed       | 2689     |
# |    total_timesteps    | 1740800  |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.591    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.176   |
# |    value_loss         | 0.142    |
# ------------------------------------
# Eval num_timesteps=1769472, episode_reward=-21.00 +/- 0.00
# Episode length: 3071.25 +/- 59.06
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.07e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1769472  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.316    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1727     |
# |    policy_loss        | 0.339    |
# |    value_loss         | 0.279    |
# ------------------------------------
# Eval num_timesteps=1835008, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1835008  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.471    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1791     |
# |    policy_loss        | -0.151   |
# |    value_loss         | 0.171    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.73e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 647      |
# |    iterations         | 1800     |
# |    time_elapsed       | 2847     |
# |    total_timesteps    | 1843200  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.372    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.081    |
# |    value_loss         | 0.205    |
# ------------------------------------
# Eval num_timesteps=1900544, episode_reward=-21.00 +/- 0.00
# Episode length: 3105.00 +/- 55.56
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.1e+03  |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1900544  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.408    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1855     |
# |    policy_loss        | -0.162   |
# |    value_loss         | 0.144    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.71e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 650      |
# |    iterations         | 1900     |
# |    time_elapsed       | 2991     |
# |    total_timesteps    | 1945600  |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.603    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.0175   |
# |    value_loss         | 0.16     |
# ------------------------------------
# Eval num_timesteps=1966080, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 1966080  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.652    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1919     |
# |    policy_loss        | -0.386   |
# |    value_loss         | 0.202    |
# ------------------------------------
# Eval num_timesteps=2031616, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2031616  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.295    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1983     |
# |    policy_loss        | 0.0263   |
# |    value_loss         | 0.354    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.72e+03 |
# |    ep_rew_mean        | -20.3    |
# | time/                 |          |
# |    fps                | 649      |
# |    iterations         | 2000     |
# |    time_elapsed       | 3151     |
# |    total_timesteps    | 2048000  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.572    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.532   |
# |    value_loss         | 0.215    |
# ------------------------------------
# Eval num_timesteps=2097152, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2097152  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.307    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2047     |
# |    policy_loss        | -0.0522  |
# |    value_loss         | 0.398    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.78e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 652      |
# |    iterations         | 2100     |
# |    time_elapsed       | 3295     |
# |    total_timesteps    | 2150400  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.217    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.0213  |
# |    value_loss         | 0.255    |
# ------------------------------------
# Eval num_timesteps=2162688, episode_reward=-21.00 +/- 0.00
# Episode length: 3071.00 +/- 58.09
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.07e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2162688  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.415    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2111     |
# |    policy_loss        | -0.0256  |
# |    value_loss         | 0.232    |
# ------------------------------------
# Eval num_timesteps=2228224, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2228224  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.146    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2175     |
# |    policy_loss        | 0.721    |
# |    value_loss         | 0.734    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.94e+03 |
# |    ep_rew_mean        | -20      |
# | time/                 |          |
# |    fps                | 652      |
# |    iterations         | 2200     |
# |    time_elapsed       | 3453     |
# |    total_timesteps    | 2252800  |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.734    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.014   |
# |    value_loss         | 0.0861   |
# ------------------------------------
# Eval num_timesteps=2293760, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2293760  |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.529    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2239     |
# |    policy_loss        | 0.477    |
# |    value_loss         | 0.26     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.88e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 654      |
# |    iterations         | 2300     |
# |    time_elapsed       | 3597     |
# |    total_timesteps    | 2355200  |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.358    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.325    |
# |    value_loss         | 0.218    |
# ------------------------------------
# Eval num_timesteps=2359296, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2359296  |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | 0.224    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2303     |
# |    policy_loss        | 0.0709   |
# |    value_loss         | 0.313    |
# ------------------------------------
# Eval num_timesteps=2424832, episode_reward=-21.00 +/- 0.00
# Episode length: 3071.50 +/- 60.03
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.07e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2424832  |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.217    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2367     |
# |    policy_loss        | 0.319    |
# |    value_loss         | 0.455    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.96e+03 |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 654      |
# |    iterations         | 2400     |
# |    time_elapsed       | 3754     |
# |    total_timesteps    | 2457600  |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.228    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0648   |
# |    value_loss         | 0.304    |
# ------------------------------------
# Eval num_timesteps=2490368, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2490368  |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.602    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2431     |
# |    policy_loss        | -0.00457 |
# |    value_loss         | 0.0912   |
# ------------------------------------
# Eval num_timesteps=2555904, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2555904  |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.0885   |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2495     |
# |    policy_loss        | 0.407    |
# |    value_loss         | 0.605    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.96e+03 |
# |    ep_rew_mean        | -20.1    |
# | time/                 |          |
# |    fps                | 654      |
# |    iterations         | 2500     |
# |    time_elapsed       | 3912     |
# |    total_timesteps    | 2560000  |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.338    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.588   |
# |    value_loss         | 0.239    |
# ------------------------------------
# Eval num_timesteps=2621440, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2621440  |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.282    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2559     |
# |    policy_loss        | 0.03     |
# |    value_loss         | 0.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.01e+03 |
# |    ep_rew_mean        | -20      |
# | time/                 |          |
# |    fps                | 655      |
# |    iterations         | 2600     |
# |    time_elapsed       | 4062     |
# |    total_timesteps    | 2662400  |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.195    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0263  |
# |    value_loss         | 0.397    |
# ------------------------------------
# Eval num_timesteps=2686976, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2686976  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.265    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2623     |
# |    policy_loss        | -0.368   |
# |    value_loss         | 0.251    |
# ------------------------------------
# Eval num_timesteps=2752512, episode_reward=-21.00 +/- 0.00
# Episode length: 3148.75 +/- 119.74
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.15e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2752512  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.345    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2687     |
# |    policy_loss        | -0.285   |
# |    value_loss         | 0.204    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.03e+03 |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 653      |
# |    iterations         | 2700     |
# |    time_elapsed       | 4229     |
# |    total_timesteps    | 2764800  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.105    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.179   |
# |    value_loss         | 0.477    |
# ------------------------------------
# Eval num_timesteps=2818048, episode_reward=-21.00 +/- 0.00
# Episode length: 3148.25 +/- 147.06
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.15e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2818048  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.49     |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2751     |
# |    policy_loss        | 0.158    |
# |    value_loss         | 0.298    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.06e+03 |
# |    ep_rew_mean        | -19.8    |
# | time/                 |          |
# |    fps                | 654      |
# |    iterations         | 2800     |
# |    time_elapsed       | 4382     |
# |    total_timesteps    | 2867200  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.241    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.215    |
# |    value_loss         | 0.371    |
# ------------------------------------
# Eval num_timesteps=2883584, episode_reward=-21.00 +/- 0.00
# Episode length: 3102.50 +/- 96.80
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.1e+03  |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2883584  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.166    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2815     |
# |    policy_loss        | -0.0614  |
# |    value_loss         | 0.391    |
# ------------------------------------
# Eval num_timesteps=2949120, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 2949120  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.162    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2879     |
# |    policy_loss        | -0.021   |
# |    value_loss         | 0.361    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.01e+03 |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 652      |
# |    iterations         | 2900     |
# |    time_elapsed       | 4550     |
# |    total_timesteps    | 2969600  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.342    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.278    |
# |    value_loss         | 0.232    |
# ------------------------------------
# Eval num_timesteps=3014656, episode_reward=-21.00 +/- 0.00
# Episode length: 3056.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.06e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 3014656  |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.207    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2943     |
# |    policy_loss        | 0.134    |
# |    value_loss         | 0.461    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.15e+03 |
# |    ep_rew_mean        | -19.9    |
# | time/                 |          |
# |    fps                | 653      |
# |    iterations         | 3000     |
# |    time_elapsed       | 4702     |
# |    total_timesteps    | 3072000  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.462    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0565   |
# |    value_loss         | 0.181    |
# ------------------------------------
# Eval num_timesteps=3080192, episode_reward=-21.00 +/- 0.00
# Episode length: 3117.25 +/- 162.05
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 3.12e+03 |
# |    mean_reward        | -21      |
# | time/                 |          |
# |    total_timesteps    | 3080192  |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.311    |
# |    learning_rate      | 0.00025  |
# ...
# |    learning_rate      | 0.00025  |
# |    n_updates          | 8703     |
# |    policy_loss        | 0.0293   |
# |    value_loss         | 0.0807   |
# ------------------------------------
# Eval num_timesteps=8978432, episode_reward=13.88 +/- 4.74
# Episode length: 10502.88 +/- 1812.93
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 1.05e+04 |
# |    mean_reward        | 13.9     |
# | time/                 |          |
# |    total_timesteps    | 8978432  |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.582    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 8767     |
# |    policy_loss        | 0.0328   |
# |    value_loss         | 0.109    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.11e+04 |
# |    ep_rew_mean        | 10.2     |
# | time/                 |          |
# |    fps                | 510      |
# |    iterations         | 8800     |
# |    time_elapsed       | 17635    |
# |    total_timesteps    | 9011200  |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.574    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 8799     |
# |    policy_loss        | -0.0143  |
# |    value_loss         | 0.102    |
# ------------------------------------
# Eval num_timesteps=9043968, episode_reward=17.12 +/- 3.89
# Episode length: 9276.62 +/- 1179.06
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 9.28e+03 |
# |    mean_reward        | 17.1     |
# | time/                 |          |
# |    total_timesteps    | 9043968  |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.608    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 8831     |
# |    policy_loss        | 0.191    |
# |    value_loss         | 0.102    |
# ------------------------------------
# Eval num_timesteps=9109504, episode_reward=17.19 +/- 2.48
# Episode length: 9165.31 +/- 636.50
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 9.17e+03 |
# |    mean_reward        | 17.2     |
# | time/                 |          |
# |    total_timesteps    | 9109504  |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.492    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 8895     |
# |    policy_loss        | -0.0442  |
# |    value_loss         | 0.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.09e+04 |
# |    ep_rew_mean        | 10.9     |
# | time/                 |          |
# |    fps                | 510      |
# |    iterations         | 8900     |
# |    time_elapsed       | 17858    |
# |    total_timesteps    | 9113600  |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.458    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 8899     |
# |    policy_loss        | -0.0257  |
# |    value_loss         | 0.176    |
# ------------------------------------
# Eval num_timesteps=9175040, episode_reward=17.12 +/- 4.30
# Episode length: 9085.44 +/- 1050.82
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 9.09e+03 |
# |    mean_reward        | 17.1     |
# | time/                 |          |
# |    total_timesteps    | 9175040  |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.487    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 8959     |
# |    policy_loss        | 0.0195   |
# |    value_loss         | 0.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.05e+04 |
# |    ep_rew_mean        | 12.1     |
# | time/                 |          |
# |    fps                | 510      |
# |    iterations         | 9000     |
# |    time_elapsed       | 18036    |
# |    total_timesteps    | 9216000  |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.49     |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 8999     |
# |    policy_loss        | 0.139    |
# |    value_loss         | 0.0983   |
# ------------------------------------
# Eval num_timesteps=9240576, episode_reward=16.31 +/- 6.21
# Episode length: 9514.44 +/- 1929.66
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 9.51e+03 |
# |    mean_reward        | 16.3     |
# | time/                 |          |
# |    total_timesteps    | 9240576  |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.524    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9023     |
# |    policy_loss        | -0.162   |
# |    value_loss         | 0.145    |
# ------------------------------------
# Eval num_timesteps=9306112, episode_reward=19.06 +/- 1.98
# Episode length: 8556.50 +/- 540.06
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 8.56e+03 |
# |    mean_reward        | 19.1     |
# | time/                 |          |
# |    total_timesteps    | 9306112  |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.523    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9087     |
# |    policy_loss        | -0.0797  |
# |    value_loss         | 0.126    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.06e+04 |
# |    ep_rew_mean        | 12.1     |
# | time/                 |          |
# |    fps                | 510      |
# |    iterations         | 9100     |
# |    time_elapsed       | 18264    |
# |    total_timesteps    | 9318400  |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.411    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9099     |
# |    policy_loss        | -0.0492  |
# |    value_loss         | 0.225    |
# ------------------------------------
# Eval num_timesteps=9371648, episode_reward=9.44 +/- 4.47
# Episode length: 11580.69 +/- 1465.75
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 1.16e+04 |
# |    mean_reward        | 9.44     |
# | time/                 |          |
# |    total_timesteps    | 9371648  |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 0.624    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9151     |
# |    policy_loss        | 0.0997   |
# |    value_loss         | 0.095    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.05e+04 |
# |    ep_rew_mean        | 12.2     |
# | time/                 |          |
# |    fps                | 510      |
# |    iterations         | 9200     |
# |    time_elapsed       | 18458    |
# |    total_timesteps    | 9420800  |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.582    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9199     |
# |    policy_loss        | -0.205   |
# |    value_loss         | 0.182    |
# ------------------------------------
# Eval num_timesteps=9437184, episode_reward=16.50 +/- 4.91
# Episode length: 9516.12 +/- 1465.37
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 9.52e+03 |
# |    mean_reward        | 16.5     |
# | time/                 |          |
# |    total_timesteps    | 9437184  |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.556    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9215     |
# |    policy_loss        | 0.0533   |
# |    value_loss         | 0.115    |
# ------------------------------------
# Eval num_timesteps=9502720, episode_reward=16.62 +/- 5.54
# Episode length: 9482.94 +/- 1769.55
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 9.48e+03 |
# |    mean_reward        | 16.6     |
# | time/                 |          |
# |    total_timesteps    | 9502720  |
# | train/                |          |
# |    entropy_loss       | -1.5     |
# |    explained_variance | 0.606    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9279     |
# |    policy_loss        | 0.104    |
# |    value_loss         | 0.0977   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.04e+04 |
# |    ep_rew_mean        | 12.7     |
# | time/                 |          |
# |    fps                | 509      |
# |    iterations         | 9300     |
# |    time_elapsed       | 18675    |
# |    total_timesteps    | 9523200  |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.484    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9299     |
# |    policy_loss        | -0.356   |
# |    value_loss         | 0.24     |
# ------------------------------------
# Eval num_timesteps=9568256, episode_reward=16.50 +/- 5.16
# Episode length: 9530.19 +/- 1622.99
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 9.53e+03 |
# |    mean_reward        | 16.5     |
# | time/                 |          |
# |    total_timesteps    | 9568256  |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.718    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9343     |
# |    policy_loss        | 0.00545  |
# |    value_loss         | 0.0724   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+04    |
# |    ep_rew_mean        | 13.9     |
# | time/                 |          |
# |    fps                | 510      |
# |    iterations         | 9400     |
# |    time_elapsed       | 18841    |
# |    total_timesteps    | 9625600  |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.466    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9399     |
# |    policy_loss        | -0.215   |
# |    value_loss         | 0.215    |
# ------------------------------------
# Eval num_timesteps=9633792, episode_reward=18.25 +/- 2.28
# Episode length: 8928.62 +/- 651.04
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 8.93e+03 |
# |    mean_reward        | 18.2     |
# | time/                 |          |
# |    total_timesteps    | 9633792  |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.645    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9407     |
# |    policy_loss        | -0.0641  |
# |    value_loss         | 0.0904   |
# ------------------------------------
# Eval num_timesteps=9699328, episode_reward=8.81 +/- 8.65
# Episode length: 29073.19 +/- 37981.37
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 2.91e+04 |
# |    mean_reward        | 8.81     |
# | time/                 |          |
# |    total_timesteps    | 9699328  |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.579    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9471     |
# |    policy_loss        | 0.00603  |
# |    value_loss         | 0.106    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 9.65e+03 |
# |    ep_rew_mean        | 15       |
# | time/                 |          |
# |    fps                | 504      |
# |    iterations         | 9500     |
# |    time_elapsed       | 19275    |
# |    total_timesteps    | 9728000  |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.556    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9499     |
# |    policy_loss        | -0.0732  |
# |    value_loss         | 0.141    |
# ------------------------------------
# Eval num_timesteps=9764864, episode_reward=12.50 +/- 5.92
# Episode length: 10478.62 +/- 1775.24
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 1.05e+04 |
# |    mean_reward        | 12.5     |
# | time/                 |          |
# |    total_timesteps    | 9764864  |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.565    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9535     |
# |    policy_loss        | 0.221    |
# |    value_loss         | 0.0909   |
# ------------------------------------
# Eval num_timesteps=9830400, episode_reward=13.00 +/- 8.05
# Episode length: 10473.44 +/- 2562.91
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 1.05e+04 |
# |    mean_reward        | 13       |
# | time/                 |          |
# |    total_timesteps    | 9830400  |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.587    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9599     |
# |    policy_loss        | 0.161    |
# |    value_loss         | 0.127    |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.5e+03  |
# |    ep_rew_mean     | 15.2     |
# | time/              |          |
# |    fps             | 504      |
# |    iterations      | 9600     |
# |    time_elapsed    | 19501    |
# |    total_timesteps | 9830400  |
# ---------------------------------
# Eval num_timesteps=9895936, episode_reward=16.50 +/- 6.53
# Episode length: 8757.75 +/- 2239.09
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 8.76e+03 |
# |    mean_reward        | 16.5     |
# | time/                 |          |
# |    total_timesteps    | 9895936  |
# | train/                |          |
# |    entropy_loss       | -1.62    |
# |    explained_variance | 0.621    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9663     |
# |    policy_loss        | 0.0253   |
# |    value_loss         | 0.0865   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 9.41e+03 |
# |    ep_rew_mean        | 15.4     |
# | time/                 |          |
# |    fps                | 504      |
# |    iterations         | 9700     |
# |    time_elapsed       | 19682    |
# |    total_timesteps    | 9932800  |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.657    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9699     |
# |    policy_loss        | 0.0453   |
# |    value_loss         | 0.0672   |
# ------------------------------------
# Eval num_timesteps=9961472, episode_reward=14.06 +/- 7.74
# Episode length: 9912.75 +/- 2515.51
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 9.91e+03 |
# |    mean_reward        | 14.1     |
# | time/                 |          |
# |    total_timesteps    | 9961472  |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.726    |
# |    learning_rate      | 0.00025  |
# |    n_updates          | 9727     |
# |    policy_loss        | 0.0482   |
# |    value_loss         | 0.0408   |
# ------------------------------------

# %%
# Load the results from the log directory
results_a2c = load_results(LOG_DIR_A2C)

# Display the first 50 rows of the DataFrame
print(results_a2c.head(50))

# Plot rewards over episode index
plt.figure(figsize=(12, 6))
plt.plot(results_a2c.index, results_a2c['r'], label='A2C', color = 'orange')
plt.xlabel('Episode')
plt.ylabel('Total Reward per Episode')
plt.legend()
plt.show()
# Out:
#     index     r     l          t
# 0       0 -21.0  3296  21.254553
# 1       0 -21.0  3300  21.286794
# 2       0 -20.0  3547  21.984628
# 3       0 -20.0  3607  22.178442
# 4       0 -21.0  3611  22.324825
# 5       0 -21.0  3658  22.458313
# 6       0 -20.0  4024  23.326391
# 7       0 -20.0  4242  23.987756
# 8       1 -21.0  3168  29.663404
# 9       1 -20.0  3591  30.954260
# 10      1 -20.0  3367  31.033541
# 11      1 -20.0  3348  31.183288
# 12      1 -21.0  3540  31.645898
# 13      1 -21.0  3286  32.089650
# 14      1 -21.0  3648  33.751044
# 15      1 -19.0  4238  33.793221
# 16      2 -21.0  3296  39.860815
# 17      2 -21.0  3286  39.958400
# 18      2 -20.0  4040  40.598095
# 19      2 -20.0  3783  41.101307
# 20      2 -20.0  3542  41.540833
# 21      2 -21.0  3876  42.042778
# 22      2 -21.0  3296  42.457860
# 23      2 -18.0  4877  46.746575
# 24      3 -21.0  3244  49.334467
# 25      3 -21.0  3544  49.420109
# 26      3 -20.0  3595  49.695423
# 27      3 -20.0  3350  50.154279
# 28      3 -21.0  3131  50.912544
# 29      3 -20.0  3370  51.123419
# 30      3 -20.0  3798  51.753999
# 31      3 -21.0  3595  56.239795
# 32      4 -21.0  3168  57.675676
# 33      4 -20.0  3462  58.596036
# 34      4 -20.0  3370  58.625675
# 35      4 -21.0  3296  58.814370
# 36      4 -21.0  3304  59.728523
# 37      4 -21.0  3296  59.886309
# 38      4 -20.0  3479  60.996930
# 39      5 -21.0  3168  66.042490
# 40      5 -21.0  3296  67.231655
# 41      5 -20.0  3485  67.821580
# 42      5 -21.0  3243  68.259230
# 43      4 -20.0  4663  68.696644
# 44      5 -21.0  3296  69.760479
# 45      5 -17.0  4659  71.493639
# 46      5 -20.0  4314  71.590889
# 47      6 -21.0  3408  75.475273
# 48      6 -21.0  3131  76.491719
# 49      6 -20.0  3592  77.178973

# %%
video_folder = "logs/videos/"
video_length = 1000# Record the video

env = VecVideoRecorder(train_env_a2c, video_folder,
                       record_video_trigger=lambda x: x == 0, video_length=video_length,
                       name_prefix=f"trained-agent-{ENV_ID}")

# Reset the environment
obs = env.reset()

# Run the environment for the specified number of steps using the trained model
for _ in range(video_length + 1):
    action, _ = agent_a2c.predict(obs)  # Predict the action using the trained model
    obs, _, _, _ = env.step(action)  # Take the action in the environment

# Close the VecVideoRecorder and save the video
env.close()

# Function to display the video
def show_video(video_path):
    mp4 = open(video_path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML(f'<video width="480" height="320" controls><source src="{data_url}" type="video/mp4"></video>')

# Display the video
show_video(video_folder + f"trained-agent-{ENV_ID}-step-0-to-step-{video_length}.mp4")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Saving video to /content/logs/videos/trained-agent-PongNoFrameskip-v4-step-0-to-step-1000.mp4
# Moviepy - Building video /content/logs/videos/trained-agent-PongNoFrameskip-v4-step-0-to-step-1000.mp4.
# Moviepy - Writing video /content/logs/videos/trained-agent-PongNoFrameskip-v4-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/logs/videos/trained-agent-PongNoFrameskip-v4-step-0-to-step-1000.mp4
# <video width="480" height="320" controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %%
# Train the DQN agent
agent_dqn = model_dqn.learn(total_timesteps = TOTAL_TIMESTEPS, callback =  eval_callback_dqn)
agent_dqn.save(MODEL_PATH_DQN)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7f46bc9ea890> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f46e6bfa7d0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00392  |
# |    n_updates        | 230595   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.11e+03 |
# |    ep_rew_mean      | -11.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4572     |
# |    fps              | 432      |
# |    time_elapsed     | 17061    |
# |    total_timesteps  | 7386456  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00357  |
# |    n_updates        | 230795   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.07e+03 |
# |    ep_rew_mean      | -12      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4576     |
# |    fps              | 433      |
# |    time_elapsed     | 17073    |
# |    total_timesteps  | 7396000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00493  |
# |    n_updates        | 231093   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.07e+03 |
# |    ep_rew_mean      | -11.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4580     |
# |    fps              | 433      |
# |    time_elapsed     | 17083    |
# |    total_timesteps  | 7404280  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00849  |
# |    n_updates        | 231352   |
# ----------------------------------
# Eval num_timesteps=7405568, episode_reward=-8.94 +/- 5.88
# Episode length: 10618.50 +/- 2793.94
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.06e+04 |
# |    mean_reward      | -8.94    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7405568  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00232  |
# |    n_updates        | 231392   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.99e+03 |
# |    ep_rew_mean      | -12      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4584     |
# |    fps              | 432      |
# |    time_elapsed     | 17143    |
# |    total_timesteps  | 7411904  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00689  |
# |    n_updates        | 231590   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.92e+03 |
# |    ep_rew_mean      | -12.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4588     |
# |    fps              | 432      |
# |    time_elapsed     | 17152    |
# |    total_timesteps  | 7419304  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 231822   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.89e+03 |
# |    ep_rew_mean      | -12.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4592     |
# |    fps              | 432      |
# |    time_elapsed     | 17163    |
# |    total_timesteps  | 7427800  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00274  |
# |    n_updates        | 232087   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.86e+03 |
# |    ep_rew_mean      | -12.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4596     |
# |    fps              | 432      |
# |    time_elapsed     | 17173    |
# |    total_timesteps  | 7436264  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00622  |
# |    n_updates        | 232352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.78e+03 |
# |    ep_rew_mean      | -12.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4600     |
# |    fps              | 433      |
# |    time_elapsed     | 17180    |
# |    total_timesteps  | 7441152  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00293  |
# |    n_updates        | 232504   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.76e+03 |
# |    ep_rew_mean      | -12.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4604     |
# |    fps              | 433      |
# |    time_elapsed     | 17194    |
# |    total_timesteps  | 7452808  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00222  |
# |    n_updates        | 232869   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.77e+03 |
# |    ep_rew_mean      | -12.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4608     |
# |    fps              | 433      |
# |    time_elapsed     | 17201    |
# |    total_timesteps  | 7458584  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00641  |
# |    n_updates        | 233049   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.72e+03 |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4612     |
# |    fps              | 433      |
# |    time_elapsed     | 17215    |
# |    total_timesteps  | 7469528  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00648  |
# |    n_updates        | 233391   |
# ----------------------------------
# Eval num_timesteps=7471104, episode_reward=-14.38 +/- 4.27
# Episode length: 8172.19 +/- 1852.51
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 8.17e+03 |
# |    mean_reward      | -14.4    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7471104  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00381  |
# |    n_updates        | 233440   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.72e+03 |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4616     |
# |    fps              | 433      |
# |    time_elapsed     | 17264    |
# |    total_timesteps  | 7476216  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00162  |
# |    n_updates        | 233600   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.73e+03 |
# |    ep_rew_mean      | -12.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4620     |
# |    fps              | 433      |
# |    time_elapsed     | 17278    |
# |    total_timesteps  | 7487344  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00223  |
# |    n_updates        | 233948   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.74e+03 |
# |    ep_rew_mean      | -12.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4624     |
# |    fps              | 433      |
# |    time_elapsed     | 17290    |
# |    total_timesteps  | 7496472  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.01     |
# |    n_updates        | 234233   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.7e+03  |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4628     |
# |    fps              | 433      |
# |    time_elapsed     | 17298    |
# |    total_timesteps  | 7502968  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 234436   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.65e+03 |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4632     |
# |    fps              | 434      |
# |    time_elapsed     | 17311    |
# |    total_timesteps  | 7513984  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00441  |
# |    n_updates        | 234780   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.66e+03 |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4636     |
# |    fps              | 434      |
# |    time_elapsed     | 17319    |
# |    total_timesteps  | 7519728  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00391  |
# |    n_updates        | 234960   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.62e+03 |
# |    ep_rew_mean      | -12.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4640     |
# |    fps              | 434      |
# |    time_elapsed     | 17333    |
# |    total_timesteps  | 7531264  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0068   |
# |    n_updates        | 235320   |
# ----------------------------------
# Eval num_timesteps=7536640, episode_reward=-11.44 +/- 3.66
# Episode length: 9376.62 +/- 1449.52
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.38e+03 |
# |    mean_reward      | -11.4    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7536640  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00358  |
# |    n_updates        | 235488   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.65e+03 |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4644     |
# |    fps              | 433      |
# |    time_elapsed     | 17382    |
# |    total_timesteps  | 7537272  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00224  |
# |    n_updates        | 235508   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.65e+03 |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4648     |
# |    fps              | 433      |
# |    time_elapsed     | 17397    |
# |    total_timesteps  | 7549240  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00233  |
# |    n_updates        | 235882   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.63e+03 |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4652     |
# |    fps              | 434      |
# |    time_elapsed     | 17404    |
# |    total_timesteps  | 7555080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00148  |
# |    n_updates        | 236065   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.54e+03 |
# |    ep_rew_mean      | -12.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4656     |
# |    fps              | 434      |
# |    time_elapsed     | 17413    |
# |    total_timesteps  | 7562544  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00577  |
# |    n_updates        | 236298   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.45e+03 |
# |    ep_rew_mean      | -12.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4660     |
# |    fps              | 434      |
# |    time_elapsed     | 17431    |
# |    total_timesteps  | 7576904  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00741  |
# |    n_updates        | 236747   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.51e+03 |
# |    ep_rew_mean      | -12.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4664     |
# |    fps              | 434      |
# |    time_elapsed     | 17437    |
# |    total_timesteps  | 7581696  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00772  |
# |    n_updates        | 236896   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.51e+03 |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4668     |
# |    fps              | 435      |
# |    time_elapsed     | 17451    |
# |    total_timesteps  | 7592552  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00472  |
# |    n_updates        | 237236   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.5e+03  |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4672     |
# |    fps              | 435      |
# |    time_elapsed     | 17461    |
# |    total_timesteps  | 7600680  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.002    |
# |    n_updates        | 237490   |
# ----------------------------------
# Eval num_timesteps=7602176, episode_reward=-12.25 +/- 5.57
# Episode length: 9601.44 +/- 2827.48
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.6e+03  |
# |    mean_reward      | -12.2    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7602176  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00507  |
# |    n_updates        | 237536   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.52e+03 |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4676     |
# |    fps              | 434      |
# |    time_elapsed     | 17526    |
# |    total_timesteps  | 7609152  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00263  |
# |    n_updates        | 237754   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.55e+03 |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4680     |
# |    fps              | 434      |
# |    time_elapsed     | 17537    |
# |    total_timesteps  | 7618016  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00214  |
# |    n_updates        | 238031   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.57e+03 |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4684     |
# |    fps              | 434      |
# |    time_elapsed     | 17548    |
# |    total_timesteps  | 7627136  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00206  |
# |    n_updates        | 238316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.6e+03  |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4688     |
# |    fps              | 434      |
# |    time_elapsed     | 17558    |
# |    total_timesteps  | 7634752  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00563  |
# |    n_updates        | 238554   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.68e+03 |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4692     |
# |    fps              | 435      |
# |    time_elapsed     | 17571    |
# |    total_timesteps  | 7644848  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00494  |
# |    n_updates        | 238870   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.69e+03 |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4696     |
# |    fps              | 435      |
# |    time_elapsed     | 17575    |
# |    total_timesteps  | 7648384  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 238980   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.75e+03 |
# |    ep_rew_mean      | -12.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4700     |
# |    fps              | 435      |
# |    time_elapsed     | 17595    |
# |    total_timesteps  | 7664584  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00201  |
# |    n_updates        | 239487   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.82e+03 |
# |    ep_rew_mean      | -12.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4704     |
# |    fps              | 435      |
# |    time_elapsed     | 17599    |
# |    total_timesteps  | 7667328  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00164  |
# |    n_updates        | 239572   |
# ----------------------------------
# Eval num_timesteps=7667712, episode_reward=-10.06 +/- 3.05
# Episode length: 10511.62 +/- 1781.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.05e+04 |
# |    mean_reward      | -10.1    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7667712  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 239584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.83e+03 |
# |    ep_rew_mean      | -12.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4708     |
# |    fps              | 434      |
# |    time_elapsed     | 17662    |
# |    total_timesteps  | 7681928  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0077   |
# |    n_updates        | 240029   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.91e+03 |
# |    ep_rew_mean      | -12.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4712     |
# |    fps              | 435      |
# |    time_elapsed     | 17670    |
# |    total_timesteps  | 7688656  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00546  |
# |    n_updates        | 240239   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.93e+03 |
# |    ep_rew_mean      | -12.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4716     |
# |    fps              | 435      |
# |    time_elapsed     | 17689    |
# |    total_timesteps  | 7703616  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00451  |
# |    n_updates        | 240706   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.95e+03 |
# |    ep_rew_mean      | -12.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4720     |
# |    fps              | 435      |
# |    time_elapsed     | 17692    |
# |    total_timesteps  | 7706568  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00389  |
# |    n_updates        | 240799   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.97e+03 |
# |    ep_rew_mean      | -12.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4724     |
# |    fps              | 435      |
# |    time_elapsed     | 17713    |
# |    total_timesteps  | 7722776  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00405  |
# |    n_updates        | 241305   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.98e+03 |
# |    ep_rew_mean      | -12.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4728     |
# |    fps              | 436      |
# |    time_elapsed     | 17717    |
# |    total_timesteps  | 7726032  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00209  |
# |    n_updates        | 241407   |
# ----------------------------------
# Eval num_timesteps=7733248, episode_reward=-15.38 +/- 4.34
# Episode length: 6581.62 +/- 2756.26
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 6.58e+03 |
# |    mean_reward      | -15.4    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7733248  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0044   |
# |    n_updates        | 241632   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.97e+03 |
# |    ep_rew_mean      | -12.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4732     |
# |    fps              | 435      |
# |    time_elapsed     | 17766    |
# |    total_timesteps  | 7736928  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00711  |
# |    n_updates        | 241747   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.96e+03 |
# |    ep_rew_mean      | -12.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4736     |
# |    fps              | 435      |
# |    time_elapsed     | 17773    |
# |    total_timesteps  | 7742184  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00249  |
# |    n_updates        | 241912   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.97e+03 |
# |    ep_rew_mean      | -12.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4740     |
# |    fps              | 435      |
# |    time_elapsed     | 17786    |
# |    total_timesteps  | 7753024  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0024   |
# |    n_updates        | 242250   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.91e+03 |
# |    ep_rew_mean      | -12.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4744     |
# |    fps              | 436      |
# |    time_elapsed     | 17796    |
# |    total_timesteps  | 7760944  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00438  |
# |    n_updates        | 242498   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.87e+03 |
# |    ep_rew_mean      | -12.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4748     |
# |    fps              | 436      |
# |    time_elapsed     | 17809    |
# |    total_timesteps  | 7771208  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00353  |
# |    n_updates        | 242819   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.92e+03 |
# |    ep_rew_mean      | -12.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4752     |
# |    fps              | 436      |
# |    time_elapsed     | 17817    |
# |    total_timesteps  | 7777656  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00373  |
# |    n_updates        | 243020   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.99e+03 |
# |    ep_rew_mean      | -12.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4756     |
# |    fps              | 436      |
# |    time_elapsed     | 17831    |
# |    total_timesteps  | 7789200  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00914  |
# |    n_updates        | 243381   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.05e+03 |
# |    ep_rew_mean      | -12.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4760     |
# |    fps              | 436      |
# |    time_elapsed     | 17839    |
# |    total_timesteps  | 7795160  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00203  |
# |    n_updates        | 243567   |
# ----------------------------------
# Eval num_timesteps=7798784, episode_reward=-15.31 +/- 5.25
# Episode length: 7792.38 +/- 2230.62
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 7.79e+03 |
# |    mean_reward      | -15.3    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7798784  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00864  |
# |    n_updates        | 243680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.99e+03 |
# |    ep_rew_mean      | -12.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4764     |
# |    fps              | 436      |
# |    time_elapsed     | 17886    |
# |    total_timesteps  | 7805216  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00262  |
# |    n_updates        | 243881   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.98e+03 |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4768     |
# |    fps              | 436      |
# |    time_elapsed     | 17899    |
# |    total_timesteps  | 7815896  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00435  |
# |    n_updates        | 244215   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.99e+03 |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4772     |
# |    fps              | 436      |
# |    time_elapsed     | 17910    |
# |    total_timesteps  | 7824848  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00674  |
# |    n_updates        | 244495   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.05e+03 |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4776     |
# |    fps              | 437      |
# |    time_elapsed     | 17925    |
# |    total_timesteps  | 7836728  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00265  |
# |    n_updates        | 244866   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.99e+03 |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4780     |
# |    fps              | 437      |
# |    time_elapsed     | 17932    |
# |    total_timesteps  | 7842160  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00526  |
# |    n_updates        | 245036   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.05e+03 |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4784     |
# |    fps              | 437      |
# |    time_elapsed     | 17949    |
# |    total_timesteps  | 7855296  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00537  |
# |    n_updates        | 245446   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.09e+03 |
# |    ep_rew_mean      | -12.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4788     |
# |    fps              | 437      |
# |    time_elapsed     | 17950    |
# |    total_timesteps  | 7856536  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0031   |
# |    n_updates        | 245485   |
# ----------------------------------
# Eval num_timesteps=7864320, episode_reward=-11.06 +/- 4.38
# Episode length: 10113.69 +/- 2079.32
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.01e+04 |
# |    mean_reward      | -11.1    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7864320  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00681  |
# |    n_updates        | 245728   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.02e+03 |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4792     |
# |    fps              | 436      |
# |    time_elapsed     | 18019    |
# |    total_timesteps  | 7873208  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00204  |
# |    n_updates        | 246006   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.03e+03 |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4796     |
# |    fps              | 436      |
# |    time_elapsed     | 18021    |
# |    total_timesteps  | 7875192  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00242  |
# |    n_updates        | 246068   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.02e+03 |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4800     |
# |    fps              | 437      |
# |    time_elapsed     | 18039    |
# |    total_timesteps  | 7889648  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00381  |
# |    n_updates        | 246520   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.96e+03 |
# |    ep_rew_mean      | -12.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4804     |
# |    fps              | 437      |
# |    time_elapsed     | 18047    |
# |    total_timesteps  | 7895584  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00187  |
# |    n_updates        | 246705   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9e+03    |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4808     |
# |    fps              | 437      |
# |    time_elapsed     | 18065    |
# |    total_timesteps  | 7910344  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00432  |
# |    n_updates        | 247167   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.98e+03 |
# |    ep_rew_mean      | -12.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4812     |
# |    fps              | 437      |
# |    time_elapsed     | 18068    |
# |    total_timesteps  | 7912400  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00161  |
# |    n_updates        | 247231   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.95e+03 |
# |    ep_rew_mean      | -12.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4816     |
# |    fps              | 438      |
# |    time_elapsed     | 18080    |
# |    total_timesteps  | 7922008  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00255  |
# |    n_updates        | 247531   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.84e+03 |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4820     |
# |    fps              | 438      |
# |    time_elapsed     | 18086    |
# |    total_timesteps  | 7927416  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00149  |
# |    n_updates        | 247700   |
# ----------------------------------
# Eval num_timesteps=7929856, episode_reward=-11.62 +/- 6.04
# Episode length: 8957.62 +/- 1970.82
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 8.96e+03 |
# |    mean_reward      | -11.6    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7929856  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00808  |
# |    n_updates        | 247776   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.81e+03 |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4824     |
# |    fps              | 437      |
# |    time_elapsed     | 18150    |
# |    total_timesteps  | 7940104  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00274  |
# |    n_updates        | 248097   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.79e+03 |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4828     |
# |    fps              | 437      |
# |    time_elapsed     | 18156    |
# |    total_timesteps  | 7944944  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00484  |
# |    n_updates        | 248248   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.8e+03  |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4832     |
# |    fps              | 437      |
# |    time_elapsed     | 18173    |
# |    total_timesteps  | 7958336  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00238  |
# |    n_updates        | 248666   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.82e+03 |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4836     |
# |    fps              | 437      |
# |    time_elapsed     | 18177    |
# |    total_timesteps  | 7961416  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00656  |
# |    n_updates        | 248763   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.8e+03  |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4840     |
# |    fps              | 438      |
# |    time_elapsed     | 18191    |
# |    total_timesteps  | 7973488  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00203  |
# |    n_updates        | 249140   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.81e+03 |
# |    ep_rew_mean      | -12.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4844     |
# |    fps              | 438      |
# |    time_elapsed     | 18197    |
# |    total_timesteps  | 7977880  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00608  |
# |    n_updates        | 249277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.76e+03 |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4848     |
# |    fps              | 438      |
# |    time_elapsed     | 18214    |
# |    total_timesteps  | 7991448  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00245  |
# |    n_updates        | 249701   |
# ----------------------------------
# Eval num_timesteps=7995392, episode_reward=-16.06 +/- 4.70
# Episode length: 7606.25 +/- 2168.98
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 7.61e+03 |
# |    mean_reward      | -16.1    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 7995392  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0053   |
# |    n_updates        | 249824   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.82e+03 |
# |    ep_rew_mean      | -12.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4852     |
# |    fps              | 438      |
# |    time_elapsed     | 18262    |
# |    total_timesteps  | 7999016  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00932  |
# |    n_updates        | 249938   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.83e+03 |
# |    ep_rew_mean      | -12.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4856     |
# |    fps              | 438      |
# |    time_elapsed     | 18272    |
# |    total_timesteps  | 8007248  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00472  |
# |    n_updates        | 250195   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.8e+03  |
# |    ep_rew_mean      | -12.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4860     |
# |    fps              | 438      |
# |    time_elapsed     | 18281    |
# |    total_timesteps  | 8014472  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00695  |
# |    n_updates        | 250421   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.77e+03 |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4864     |
# |    fps              | 438      |
# |    time_elapsed     | 18291    |
# |    total_timesteps  | 8022592  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 250674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.75e+03 |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4868     |
# |    fps              | 438      |
# |    time_elapsed     | 18302    |
# |    total_timesteps  | 8031344  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00281  |
# |    n_updates        | 250948   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.7e+03  |
# |    ep_rew_mean      | -13.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4872     |
# |    fps              | 438      |
# |    time_elapsed     | 18312    |
# |    total_timesteps  | 8039144  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00503  |
# |    n_updates        | 251192   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.64e+03 |
# |    ep_rew_mean      | -13.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4876     |
# |    fps              | 439      |
# |    time_elapsed     | 18323    |
# |    total_timesteps  | 8047864  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00317  |
# |    n_updates        | 251464   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.65e+03 |
# |    ep_rew_mean      | -13.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4880     |
# |    fps              | 439      |
# |    time_elapsed     | 18334    |
# |    total_timesteps  | 8057240  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00228  |
# |    n_updates        | 251757   |
# ----------------------------------
# Eval num_timesteps=8060928, episode_reward=-16.56 +/- 1.97
# Episode length: 7525.00 +/- 981.84
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 7.52e+03 |
# |    mean_reward      | -16.6    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 8060928  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0047   |
# |    n_updates        | 251872   |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00235  |
# |    n_updates        | 304398   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.46e+03 |
# |    ep_rew_mean      | -10.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5640     |
# |    fps              | 452      |
# |    time_elapsed     | 21564    |
# |    total_timesteps  | 9750784  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00543  |
# |    n_updates        | 304680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.52e+03 |
# |    ep_rew_mean      | -10.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5644     |
# |    fps              | 452      |
# |    time_elapsed     | 21575    |
# |    total_timesteps  | 9760080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0013   |
# |    n_updates        | 304971   |
# ----------------------------------
# Eval num_timesteps=9764864, episode_reward=0.38 +/- 10.64
# Episode length: 35371.00 +/- 41959.67
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.54e+04 |
# |    mean_reward      | 0.375    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 9764864  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0028   |
# |    n_updates        | 305120   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47e+03 |
# |    ep_rew_mean      | -10.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5648     |
# |    fps              | 447      |
# |    time_elapsed     | 21852    |
# |    total_timesteps  | 9771664  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00826  |
# |    n_updates        | 305333   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47e+03 |
# |    ep_rew_mean      | -10.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5652     |
# |    fps              | 447      |
# |    time_elapsed     | 21861    |
# |    total_timesteps  | 9779088  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00993  |
# |    n_updates        | 305565   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.49e+03 |
# |    ep_rew_mean      | -10.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5656     |
# |    fps              | 447      |
# |    time_elapsed     | 21873    |
# |    total_timesteps  | 9788528  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0017   |
# |    n_updates        | 305860   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47e+03 |
# |    ep_rew_mean      | -10.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5660     |
# |    fps              | 447      |
# |    time_elapsed     | 21885    |
# |    total_timesteps  | 9798008  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 306156   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.51e+03 |
# |    ep_rew_mean      | -10.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5664     |
# |    fps              | 447      |
# |    time_elapsed     | 21893    |
# |    total_timesteps  | 9804464  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00543  |
# |    n_updates        | 306358   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.5e+03  |
# |    ep_rew_mean      | -10.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5668     |
# |    fps              | 448      |
# |    time_elapsed     | 21906    |
# |    total_timesteps  | 9815312  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00361  |
# |    n_updates        | 306697   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.54e+03 |
# |    ep_rew_mean      | -10.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5672     |
# |    fps              | 448      |
# |    time_elapsed     | 21916    |
# |    total_timesteps  | 9823352  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00229  |
# |    n_updates        | 306948   |
# ----------------------------------
# Eval num_timesteps=9830400, episode_reward=-4.38 +/- 11.71
# Episode length: 28393.94 +/- 38266.50
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.84e+04 |
# |    mean_reward      | -4.38    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 9830400  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00277  |
# |    n_updates        | 307168   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.6e+03  |
# |    ep_rew_mean      | -10.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5676     |
# |    fps              | 447      |
# |    time_elapsed     | 21976    |
# |    total_timesteps  | 9834888  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 307309   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.59e+03 |
# |    ep_rew_mean      | -10.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5680     |
# |    fps              | 447      |
# |    time_elapsed     | 21986    |
# |    total_timesteps  | 9842840  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0091   |
# |    n_updates        | 307557   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.61e+03 |
# |    ep_rew_mean      | -10.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5684     |
# |    fps              | 447      |
# |    time_elapsed     | 22000    |
# |    total_timesteps  | 9854208  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00777  |
# |    n_updates        | 307912   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.6e+03  |
# |    ep_rew_mean      | -10.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5688     |
# |    fps              | 448      |
# |    time_elapsed     | 22013    |
# |    total_timesteps  | 9864120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00673  |
# |    n_updates        | 308222   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.61e+03 |
# |    ep_rew_mean      | -10.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5692     |
# |    fps              | 448      |
# |    time_elapsed     | 22023    |
# |    total_timesteps  | 9872272  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00224  |
# |    n_updates        | 308477   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.66e+03 |
# |    ep_rew_mean      | -9.97    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5696     |
# |    fps              | 448      |
# |    time_elapsed     | 22038    |
# |    total_timesteps  | 9884768  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00383  |
# |    n_updates        | 308867   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.67e+03 |
# |    ep_rew_mean      | -9.96    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5700     |
# |    fps              | 448      |
# |    time_elapsed     | 22049    |
# |    total_timesteps  | 9893400  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00545  |
# |    n_updates        | 309137   |
# ----------------------------------
# Eval num_timesteps=9895936, episode_reward=-8.56 +/- 3.16
# Episode length: 9849.25 +/- 934.57
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.85e+03 |
# |    mean_reward      | -8.56    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 9895936  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00172  |
# |    n_updates        | 309216   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.72e+03 |
# |    ep_rew_mean      | -9.92    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5704     |
# |    fps              | 447      |
# |    time_elapsed     | 22109    |
# |    total_timesteps  | 9904800  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00333  |
# |    n_updates        | 309493   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74e+03 |
# |    ep_rew_mean      | -9.85    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5708     |
# |    fps              | 448      |
# |    time_elapsed     | 22119    |
# |    total_timesteps  | 9912048  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00373  |
# |    n_updates        | 309720   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71e+03 |
# |    ep_rew_mean      | -9.86    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5712     |
# |    fps              | 448      |
# |    time_elapsed     | 22134    |
# |    total_timesteps  | 9923176  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00612  |
# |    n_updates        | 310068   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73e+03 |
# |    ep_rew_mean      | -9.87    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5716     |
# |    fps              | 448      |
# |    time_elapsed     | 22146    |
# |    total_timesteps  | 9931888  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00431  |
# |    n_updates        | 310340   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71e+03 |
# |    ep_rew_mean      | -9.96    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5720     |
# |    fps              | 448      |
# |    time_elapsed     | 22163    |
# |    total_timesteps  | 9944216  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00536  |
# |    n_updates        | 310725   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77e+03 |
# |    ep_rew_mean      | -9.79    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5724     |
# |    fps              | 448      |
# |    time_elapsed     | 22172    |
# |    total_timesteps  | 9951360  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.005    |
# |    n_updates        | 310948   |
# ----------------------------------
# Eval num_timesteps=9961472, episode_reward=-3.88 +/- 4.08
# Episode length: 11729.88 +/- 1135.54
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.17e+04 |
# |    mean_reward      | -3.88    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 9961472  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00302  |
# |    n_updates        | 311264   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8e+03  |
# |    ep_rew_mean      | -9.73    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5728     |
# |    fps              | 447      |
# |    time_elapsed     | 22251    |
# |    total_timesteps  | 9964192  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0019   |
# |    n_updates        | 311349   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8e+03  |
# |    ep_rew_mean      | -9.69    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5732     |
# |    fps              | 447      |
# |    time_elapsed     | 22263    |
# |    total_timesteps  | 9973288  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00464  |
# |    n_updates        | 311634   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.82e+03 |
# |    ep_rew_mean      | -9.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5736     |
# |    fps              | 448      |
# |    time_elapsed     | 22281    |
# |    total_timesteps  | 9986944  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0052   |
# |    n_updates        | 312060   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.82e+03 |
# |    ep_rew_mean      | -9.54    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5740     |
# |    fps              | 448      |
# |    time_elapsed     | 22290    |
# |    total_timesteps  | 9993688  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00326  |
# |    n_updates        | 312271   |
# ----------------------------------

# %%
# Load the results from the log directory
results_dqn = load_results(LOG_DIR_DQN)

# Display the first 50 rows of the DataFrame
print(results_dqn.head(50))

# Plot rewards over episode index
plt.figure(figsize=(12, 6))
plt.plot(results_dqn.index, results_dqn['r'], label='DQN',color = 'green')
plt.xlabel('Episode')
plt.ylabel('Total Reward per Episode')
plt.legend()
plt.show()
# Out:
#     index     r     l             t
# 0       0 -21.0  3339  19849.590314
# 1       0 -21.0  3368  19849.708496
# 2       0 -20.0  3460  19849.897865
# 3       0 -20.0  3685  19850.455690
# 4       0 -20.0  3734  19850.553232
# 5       0 -21.0  3764  19850.625850
# 6       0 -21.0  3888  19850.894533
# 7       0 -19.0  4148  19851.507693
# 8       1 -21.0  3168  19857.006629
# 9       1 -21.0  3056  19857.405226
# 10      1 -21.0  3168  19857.747735
# 11      1 -21.0  3780  19858.152419
# 12      1 -21.0  3760  19858.208716
# 13      1 -21.0  3131  19858.581872
# 14      1 -20.0  3940  19859.414097
# 15      1 -21.0  3943  19859.810225
# 16      2 -20.0  3623  19865.622095
# 17      2 -20.0  3847  19865.774446
# 18      2 -20.0  3481  19866.092720
# 19      2 -21.0  3280  19866.842961
# 20      2 -21.0  3168  19866.970922
# 21      2 -19.0  4344  19867.676549
# 22      2 -19.0  4353  19868.098635
# 23      2 -18.0  4849  19869.627858
# 24      3 -21.0  3168  19874.165146
# 25      3 -19.0  3752  19874.329458
# 26      3 -20.0  3609  19874.346493
# 27      3 -21.0  3363  19874.539528
# 28      3 -19.0  4010  19874.839692
# 29      3 -20.0  3845  19876.878695
# 30      3 -18.0  4417  19877.712504
# 31      3 -20.0  4014  19878.740996
# 32      4 -21.0  3368  19881.798670
# 33      4 -21.0  3176  19882.008061
# 34      4 -20.0  3485  19882.404926
# 35      4 -20.0  4029  19883.519895
# 36      4 -21.0  3174  19884.141400
# 37      4 -18.0  4617  19884.912002
# 38      4 -21.0  3540  19886.847304
# 39      4 -19.0  4125  19887.114086
# 40      5 -21.0  3056  19889.404769
# 41      5 -21.0  3485  19889.798033
# 42      5 -21.0  3280  19890.984720
# 43      5 -19.0  4100  19891.407989
# 44      5 -21.0  3780  19893.435630
# 45      5 -21.0  4132  19893.530170
# 46      5 -21.0  3056  19894.047087
# 47      5 -21.0  3408  19894.569949
# 48      6 -20.0  3367  19897.488912
# 49      6 -19.0  3752  19898.007930

# %%
video_folder = "logs/videos/"
video_length = 1000# Record the video

env = VecVideoRecorder(train_env_dqn, video_folder,
                       record_video_trigger=lambda x: x == 0, video_length=video_length,
                       name_prefix=f"trained-agent-{ENV_ID}")

# Reset the environment
obs = env.reset()

# Run the environment for the specified number of steps using the trained model
for _ in range(video_length + 1):
    action, _ = agent_dqn.predict(obs)  # Predict the action using the trained model
    obs, _, _, _ = env.step(action)  # Take the action in the environment

# Close the VecVideoRecorder and save the video
env.close()

# Function to display the video
def show_video(video_path):
    mp4 = open(video_path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML(f'<video width="480" height="320" controls><source src="{data_url}" type="video/mp4"></video>')

# Display the video
show_video(video_folder + f"trained-agent-{ENV_ID}-step-0-to-step-{video_length}.mp4")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Saving video to /content/logs/videos/trained-agent-PongNoFrameskip-v4-step-0-to-step-1000.mp4
# Moviepy - Building video /content/logs/videos/trained-agent-PongNoFrameskip-v4-step-0-to-step-1000.mp4.
# Moviepy - Writing video /content/logs/videos/trained-agent-PongNoFrameskip-v4-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/logs/videos/trained-agent-PongNoFrameskip-v4-step-0-to-step-1000.mp4
# <video width="480" height="320" controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %%
# Train the PPO agent
agent_ppo = model_ppo.learn(total_timesteps = TOTAL_TIMESTEPS, callback =  eval_callback_ppo)
agent_ppo.save(MODEL_PATH_PPO)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7f46e695c280> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f46e6bfa4a0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# Streaming output truncated to the last 5000 lines.
# |    entropy_loss         | -0.741      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0233     |
# |    n_updates            | 38116       |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.58e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 9531        |
# |    time_elapsed         | 17937       |
# |    total_timesteps      | 9759744     |
# | train/                  |             |
# |    approx_kl            | 0.008733495 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.707      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0276     |
# |    n_updates            | 38120       |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00112     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.57e+03   |
# |    ep_rew_mean          | 20.9       |
# | time/                   |            |
# |    fps                  | 544        |
# |    iterations           | 9532       |
# |    time_elapsed         | 17938      |
# |    total_timesteps      | 9760768    |
# | train/                  |            |
# |    approx_kl            | 0.00884395 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.744     |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0263    |
# |    n_updates            | 38124      |
# |    policy_gradient_loss | -0.0108    |
# |    value_loss           | 0.00089    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 9533         |
# |    time_elapsed         | 17940        |
# |    total_timesteps      | 9761792      |
# | train/                  |              |
# |    approx_kl            | 0.0063713407 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0326      |
# |    n_updates            | 38128        |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 0.000678     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 9534         |
# |    time_elapsed         | 17941        |
# |    total_timesteps      | 9762816      |
# | train/                  |              |
# |    approx_kl            | 0.0055627585 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.742       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0327      |
# |    n_updates            | 38132        |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 0.000753     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 9535         |
# |    time_elapsed         | 17942        |
# |    total_timesteps      | 9763840      |
# | train/                  |              |
# |    approx_kl            | 0.0076331943 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.029       |
# |    n_updates            | 38136        |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 0.00067      |
# ------------------------------------------
# Eval num_timesteps=9764864, episode_reward=20.94 +/- 0.24
# Episode length: 6571.62 +/- 90.10
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 6.57e+03    |
# |    mean_reward          | 20.9        |
# | time/                   |             |
# |    total_timesteps      | 9764864     |
# | train/                  |             |
# |    approx_kl            | 0.006037503 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0295     |
# |    n_updates            | 38140       |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.000619    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.57e+03 |
# |    ep_rew_mean     | 20.9     |
# | time/              |          |
# |    fps             | 543      |
# |    iterations      | 9536     |
# |    time_elapsed    | 17974    |
# |    total_timesteps | 9764864  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9537         |
# |    time_elapsed         | 17976        |
# |    total_timesteps      | 9765888      |
# | train/                  |              |
# |    approx_kl            | 0.0083201155 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0275      |
# |    n_updates            | 38144        |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.000991     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9538        |
# |    time_elapsed         | 17977       |
# |    total_timesteps      | 9766912     |
# | train/                  |             |
# |    approx_kl            | 0.007428985 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.737      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0279     |
# |    n_updates            | 38148       |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.000756    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9539        |
# |    time_elapsed         | 17978       |
# |    total_timesteps      | 9767936     |
# | train/                  |             |
# |    approx_kl            | 0.007681314 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.785      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0262     |
# |    n_updates            | 38152       |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.000741    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9540         |
# |    time_elapsed         | 17980        |
# |    total_timesteps      | 9768960      |
# | train/                  |              |
# |    approx_kl            | 0.0061221994 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.742       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0244      |
# |    n_updates            | 38156        |
# |    policy_gradient_loss | -0.00931     |
# |    value_loss           | 0.000592     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.57e+03  |
# |    ep_rew_mean          | 20.9      |
# | time/                   |           |
# |    fps                  | 543       |
# |    iterations           | 9541      |
# |    time_elapsed         | 17981     |
# |    total_timesteps      | 9769984   |
# | train/                  |           |
# |    approx_kl            | 0.0066701 |
# |    clip_fraction        | 0.135     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -0.81     |
# |    explained_variance   | 0.993     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0287   |
# |    n_updates            | 38160     |
# |    policy_gradient_loss | -0.0141   |
# |    value_loss           | 0.000594  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9542        |
# |    time_elapsed         | 17983       |
# |    total_timesteps      | 9771008     |
# | train/                  |             |
# |    approx_kl            | 0.005321338 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0336     |
# |    n_updates            | 38164       |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.000708    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9543         |
# |    time_elapsed         | 17984        |
# |    total_timesteps      | 9772032      |
# | train/                  |              |
# |    approx_kl            | 0.0064280024 |
# |    clip_fraction        | 0.154        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.769       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0267      |
# |    n_updates            | 38168        |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 0.00092      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9544        |
# |    time_elapsed         | 17985       |
# |    total_timesteps      | 9773056     |
# | train/                  |             |
# |    approx_kl            | 0.006408726 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0265     |
# |    n_updates            | 38172       |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.00106     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9545         |
# |    time_elapsed         | 17987        |
# |    total_timesteps      | 9774080      |
# | train/                  |              |
# |    approx_kl            | 0.0070815375 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.823       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0279      |
# |    n_updates            | 38176        |
# |    policy_gradient_loss | -0.0129      |
# |    value_loss           | 0.000705     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9546         |
# |    time_elapsed         | 17988        |
# |    total_timesteps      | 9775104      |
# | train/                  |              |
# |    approx_kl            | 0.0058681685 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0368      |
# |    n_updates            | 38180        |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 0.000883     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9547         |
# |    time_elapsed         | 17990        |
# |    total_timesteps      | 9776128      |
# | train/                  |              |
# |    approx_kl            | 0.0105151255 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0304      |
# |    n_updates            | 38184        |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 0.00108      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.57e+03   |
# |    ep_rew_mean          | 20.9       |
# | time/                   |            |
# |    fps                  | 543        |
# |    iterations           | 9548       |
# |    time_elapsed         | 17991      |
# |    total_timesteps      | 9777152    |
# | train/                  |            |
# |    approx_kl            | 0.00622729 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.794     |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0316    |
# |    n_updates            | 38188      |
# |    policy_gradient_loss | -0.0131    |
# |    value_loss           | 0.000953   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9549        |
# |    time_elapsed         | 17992       |
# |    total_timesteps      | 9778176     |
# | train/                  |             |
# |    approx_kl            | 0.006188473 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.767      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0293     |
# |    n_updates            | 38192       |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.000693    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9550         |
# |    time_elapsed         | 17994        |
# |    total_timesteps      | 9779200      |
# | train/                  |              |
# |    approx_kl            | 0.0048239455 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.823       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0281      |
# |    n_updates            | 38196        |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 0.000881     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9551         |
# |    time_elapsed         | 17995        |
# |    total_timesteps      | 9780224      |
# | train/                  |              |
# |    approx_kl            | 0.0041339556 |
# |    clip_fraction        | 0.0886       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.783       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.029       |
# |    n_updates            | 38200        |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 0.000825     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9552        |
# |    time_elapsed         | 17997       |
# |    total_timesteps      | 9781248     |
# | train/                  |             |
# |    approx_kl            | 0.004315769 |
# |    clip_fraction        | 0.0911      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0299     |
# |    n_updates            | 38204       |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00053     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9553        |
# |    time_elapsed         | 17998       |
# |    total_timesteps      | 9782272     |
# | train/                  |             |
# |    approx_kl            | 0.005879792 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0384     |
# |    n_updates            | 38208       |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.000589    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9554         |
# |    time_elapsed         | 17999        |
# |    total_timesteps      | 9783296      |
# | train/                  |              |
# |    approx_kl            | 0.0059039616 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.799       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0293      |
# |    n_updates            | 38212        |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.000583     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9555         |
# |    time_elapsed         | 18001        |
# |    total_timesteps      | 9784320      |
# | train/                  |              |
# |    approx_kl            | 0.0063486733 |
# |    clip_fraction        | 0.162        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0337      |
# |    n_updates            | 38216        |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 0.000841     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9556        |
# |    time_elapsed         | 18002       |
# |    total_timesteps      | 9785344     |
# | train/                  |             |
# |    approx_kl            | 0.009780017 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0223     |
# |    n_updates            | 38220       |
# |    policy_gradient_loss | -0.00998    |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9557         |
# |    time_elapsed         | 18004        |
# |    total_timesteps      | 9786368      |
# | train/                  |              |
# |    approx_kl            | 0.0082833385 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.771       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0289      |
# |    n_updates            | 38224        |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 0.00147      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9558         |
# |    time_elapsed         | 18005        |
# |    total_timesteps      | 9787392      |
# | train/                  |              |
# |    approx_kl            | 0.0076457653 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0258      |
# |    n_updates            | 38228        |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 0.00126      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9559         |
# |    time_elapsed         | 18007        |
# |    total_timesteps      | 9788416      |
# | train/                  |              |
# |    approx_kl            | 0.0077253487 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0273      |
# |    n_updates            | 38232        |
# |    policy_gradient_loss | -0.0137      |
# |    value_loss           | 0.00106      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9560        |
# |    time_elapsed         | 18008       |
# |    total_timesteps      | 9789440     |
# | train/                  |             |
# |    approx_kl            | 0.010434062 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.711      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0274     |
# |    n_updates            | 38236       |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9561         |
# |    time_elapsed         | 18009        |
# |    total_timesteps      | 9790464      |
# | train/                  |              |
# |    approx_kl            | 0.0060935942 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0315      |
# |    n_updates            | 38240        |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.000743     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9562         |
# |    time_elapsed         | 18011        |
# |    total_timesteps      | 9791488      |
# | train/                  |              |
# |    approx_kl            | 0.0075627784 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.8         |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0281      |
# |    n_updates            | 38244        |
# |    policy_gradient_loss | -0.0135      |
# |    value_loss           | 0.000801     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9563        |
# |    time_elapsed         | 18012       |
# |    total_timesteps      | 9792512     |
# | train/                  |             |
# |    approx_kl            | 0.008127432 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0272     |
# |    n_updates            | 38248       |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.000849    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9564         |
# |    time_elapsed         | 18014        |
# |    total_timesteps      | 9793536      |
# | train/                  |              |
# |    approx_kl            | 0.0077158324 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.803       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0296      |
# |    n_updates            | 38252        |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 0.00096      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9565         |
# |    time_elapsed         | 18015        |
# |    total_timesteps      | 9794560      |
# | train/                  |              |
# |    approx_kl            | 0.0054903766 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0332      |
# |    n_updates            | 38256        |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 0.000716     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9566         |
# |    time_elapsed         | 18016        |
# |    total_timesteps      | 9795584      |
# | train/                  |              |
# |    approx_kl            | 0.0055579096 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0296      |
# |    n_updates            | 38260        |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.000713     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9567        |
# |    time_elapsed         | 18018       |
# |    total_timesteps      | 9796608     |
# | train/                  |             |
# |    approx_kl            | 0.009172872 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0364     |
# |    n_updates            | 38264       |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.000786    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9568        |
# |    time_elapsed         | 18019       |
# |    total_timesteps      | 9797632     |
# | train/                  |             |
# |    approx_kl            | 0.009556562 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.765      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0314     |
# |    n_updates            | 38268       |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.000999    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9569        |
# |    time_elapsed         | 18021       |
# |    total_timesteps      | 9798656     |
# | train/                  |             |
# |    approx_kl            | 0.008296149 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0327     |
# |    n_updates            | 38272       |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.000966    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9570        |
# |    time_elapsed         | 18022       |
# |    total_timesteps      | 9799680     |
# | train/                  |             |
# |    approx_kl            | 0.008292382 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.759      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0299     |
# |    n_updates            | 38276       |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.000868    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.57e+03   |
# |    ep_rew_mean          | 20.9       |
# | time/                   |            |
# |    fps                  | 543        |
# |    iterations           | 9571       |
# |    time_elapsed         | 18023      |
# |    total_timesteps      | 9800704    |
# | train/                  |            |
# |    approx_kl            | 0.00725546 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.799     |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0309    |
# |    n_updates            | 38280      |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 0.000674   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9572        |
# |    time_elapsed         | 18025       |
# |    total_timesteps      | 9801728     |
# | train/                  |             |
# |    approx_kl            | 0.014366054 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0288     |
# |    n_updates            | 38284       |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.000821    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9573         |
# |    time_elapsed         | 18026        |
# |    total_timesteps      | 9802752      |
# | train/                  |              |
# |    approx_kl            | 0.0072872485 |
# |    clip_fraction        | 0.0999       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.778       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0367      |
# |    n_updates            | 38288        |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 0.0008       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9574         |
# |    time_elapsed         | 18028        |
# |    total_timesteps      | 9803776      |
# | train/                  |              |
# |    approx_kl            | 0.0060837115 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.839       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0305      |
# |    n_updates            | 38292        |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 0.000775     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9575        |
# |    time_elapsed         | 18029       |
# |    total_timesteps      | 9804800     |
# | train/                  |             |
# |    approx_kl            | 0.007224194 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0317     |
# |    n_updates            | 38296       |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9576         |
# |    time_elapsed         | 18031        |
# |    total_timesteps      | 9805824      |
# | train/                  |              |
# |    approx_kl            | 0.0060657384 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0297      |
# |    n_updates            | 38300        |
# |    policy_gradient_loss | -0.0129      |
# |    value_loss           | 0.000901     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9577        |
# |    time_elapsed         | 18032       |
# |    total_timesteps      | 9806848     |
# | train/                  |             |
# |    approx_kl            | 0.006629147 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0298     |
# |    n_updates            | 38304       |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.000863    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9578        |
# |    time_elapsed         | 18033       |
# |    total_timesteps      | 9807872     |
# | train/                  |             |
# |    approx_kl            | 0.007917206 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0246     |
# |    n_updates            | 38308       |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.000686    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9579         |
# |    time_elapsed         | 18035        |
# |    total_timesteps      | 9808896      |
# | train/                  |              |
# |    approx_kl            | 0.0062924055 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0307      |
# |    n_updates            | 38312        |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 0.00058      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9580        |
# |    time_elapsed         | 18036       |
# |    total_timesteps      | 9809920     |
# | train/                  |             |
# |    approx_kl            | 0.007300377 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0262     |
# |    n_updates            | 38316       |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.000771    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9581         |
# |    time_elapsed         | 18038        |
# |    total_timesteps      | 9810944      |
# | train/                  |              |
# |    approx_kl            | 0.0089504775 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.788       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0336      |
# |    n_updates            | 38320        |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 0.000687     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.57e+03     |
# |    ep_rew_mean          | 20.9         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9582         |
# |    time_elapsed         | 18039        |
# |    total_timesteps      | 9811968      |
# | train/                  |              |
# |    approx_kl            | 0.0059751063 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.809       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0258      |
# |    n_updates            | 38324        |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 0.000781     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9583        |
# |    time_elapsed         | 18040       |
# |    total_timesteps      | 9812992     |
# | train/                  |             |
# |    approx_kl            | 0.006760117 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.1         |
# ...
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9749        |
# |    time_elapsed         | 18365       |
# |    total_timesteps      | 9982976     |
# | train/                  |             |
# |    approx_kl            | 0.008542617 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0315     |
# |    n_updates            | 38992       |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.000889    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.63e+03     |
# |    ep_rew_mean          | 20.7         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9750         |
# |    time_elapsed         | 18367        |
# |    total_timesteps      | 9984000      |
# | train/                  |              |
# |    approx_kl            | 0.0076685585 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0303      |
# |    n_updates            | 38996        |
# |    policy_gradient_loss | -0.0137      |
# |    value_loss           | 0.000675     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.63e+03     |
# |    ep_rew_mean          | 20.7         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9751         |
# |    time_elapsed         | 18368        |
# |    total_timesteps      | 9985024      |
# | train/                  |              |
# |    approx_kl            | 0.0055050123 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0227      |
# |    n_updates            | 39000        |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 0.000671     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9752        |
# |    time_elapsed         | 18370       |
# |    total_timesteps      | 9986048     |
# | train/                  |             |
# |    approx_kl            | 0.008370001 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.715      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0314     |
# |    n_updates            | 39004       |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.000818    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9753        |
# |    time_elapsed         | 18371       |
# |    total_timesteps      | 9987072     |
# | train/                  |             |
# |    approx_kl            | 0.008031245 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.746      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0328     |
# |    n_updates            | 39008       |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.00067     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9754        |
# |    time_elapsed         | 18372       |
# |    total_timesteps      | 9988096     |
# | train/                  |             |
# |    approx_kl            | 0.007353166 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0263     |
# |    n_updates            | 39012       |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.000648    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9755        |
# |    time_elapsed         | 18374       |
# |    total_timesteps      | 9989120     |
# | train/                  |             |
# |    approx_kl            | 0.011421183 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0285     |
# |    n_updates            | 39016       |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.000762    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9756        |
# |    time_elapsed         | 18375       |
# |    total_timesteps      | 9990144     |
# | train/                  |             |
# |    approx_kl            | 0.009656379 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0261     |
# |    n_updates            | 39020       |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.00068     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.63e+03     |
# |    ep_rew_mean          | 20.7         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9757         |
# |    time_elapsed         | 18377        |
# |    total_timesteps      | 9991168      |
# | train/                  |              |
# |    approx_kl            | 0.0072737923 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.709       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0261      |
# |    n_updates            | 39024        |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 0.000402     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.63e+03     |
# |    ep_rew_mean          | 20.7         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9758         |
# |    time_elapsed         | 18378        |
# |    total_timesteps      | 9992192      |
# | train/                  |              |
# |    approx_kl            | 0.0079294825 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.806       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0292      |
# |    n_updates            | 39028        |
# |    policy_gradient_loss | -0.0129      |
# |    value_loss           | 0.000458     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9759        |
# |    time_elapsed         | 18379       |
# |    total_timesteps      | 9993216     |
# | train/                  |             |
# |    approx_kl            | 0.005976089 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.82       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0314     |
# |    n_updates            | 39032       |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.000496    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.62e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9760        |
# |    time_elapsed         | 18381       |
# |    total_timesteps      | 9994240     |
# | train/                  |             |
# |    approx_kl            | 0.006186424 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.738      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0342     |
# |    n_updates            | 39036       |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.000567    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.62e+03   |
# |    ep_rew_mean          | 20.7       |
# | time/                   |            |
# |    fps                  | 543        |
# |    iterations           | 9761       |
# |    time_elapsed         | 18382      |
# |    total_timesteps      | 9995264    |
# | train/                  |            |
# |    approx_kl            | 0.00909833 |
# |    clip_fraction        | 0.128      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.762     |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0294    |
# |    n_updates            | 39040      |
# |    policy_gradient_loss | -0.00886   |
# |    value_loss           | 0.00251    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.62e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9762        |
# |    time_elapsed         | 18384       |
# |    total_timesteps      | 9996288     |
# | train/                  |             |
# |    approx_kl            | 0.009201775 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.737      |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0206     |
# |    n_updates            | 39044       |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.00512     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.62e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9763        |
# |    time_elapsed         | 18385       |
# |    total_timesteps      | 9997312     |
# | train/                  |             |
# |    approx_kl            | 0.012226228 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0259     |
# |    n_updates            | 39048       |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00805     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.62e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9764        |
# |    time_elapsed         | 18387       |
# |    total_timesteps      | 9998336     |
# | train/                  |             |
# |    approx_kl            | 0.008256042 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.794      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0189     |
# |    n_updates            | 39052       |
# |    policy_gradient_loss | -0.00981    |
# |    value_loss           | 0.00272     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.62e+03     |
# |    ep_rew_mean          | 20.7         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 9765         |
# |    time_elapsed         | 18388        |
# |    total_timesteps      | 9999360      |
# | train/                  |              |
# |    approx_kl            | 0.0081002675 |
# |    clip_fraction        | 0.0876       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.74        |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0151      |
# |    n_updates            | 39056        |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 0.00687      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63e+03    |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9766        |
# |    time_elapsed         | 18389       |
# |    total_timesteps      | 10000384    |
# | train/                  |             |
# |    approx_kl            | 0.007288861 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.708      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0284     |
# |    n_updates            | 39060       |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.0036      |
# -----------------------------------------

# %%
# Load the results from the log directory
results_ppo = load_results(LOG_DIR_PPO)

# Display the first 50 rows of the DataFrame
print(results_ppo.head(50))

# Plot rewards over episode index
plt.figure(figsize=(12, 6))
plt.plot(results_ppo.index, results_ppo['r'], label='PPO', color = 'blue')
plt.xlabel('Episode')
plt.ylabel('Total Reward per Episode')
plt.legend()
plt.show()
# Out:
#     index     r     l             t
# 0       0 -21.0  3168  42170.635483
# 1       0 -20.0  3370  42171.172319
# 2       0 -21.0  3416  42171.372869
# 3       0 -20.0  3481  42171.497216
# 4       0 -20.0  3485  42171.515601
# 5       0 -21.0  3489  42171.548752
# 6       0 -20.0  3588  42171.845340
# 7       0 -19.0  3985  42173.036754
# 8       1 -21.0  3493  42181.794089
# 9       1 -19.0  4014  42182.283345
# 10      1 -20.0  3607  42182.355926
# 11      1 -20.0  3840  42182.834577
# 12      1 -20.0  3902  42182.917225
# 13      1 -20.0  3972  42183.255213
# 14      1 -20.0  4210  42183.511898
# 15      1 -20.0  3719  42183.888161
# 16      2 -21.0  3243  42191.294457
# 17      2 -21.0  3131  42191.677953
# 18      2 -20.0  3367  42192.260199
# 19      2 -20.0  3374  42192.664208
# 20      2 -21.0  3280  42193.185227
# 21      2 -20.0  3839  42193.934210
# 22      2 -20.0  3647  42194.574170
# 23      2 -20.0  3955  42194.791344
# 24      3 -19.0  3667  42201.524900
# 25      3 -20.0  3481  42202.074964
# 26      3 -21.0  3355  42202.165331
# 27      3 -18.0  4319  42203.719115
# 28      3 -21.0  3888  42203.944342
# 29      3 -19.0  3832  42204.704420
# 30      3 -21.0  3776  42205.069107
# 31      3 -20.0  4431  42206.949577
# 32      4 -21.0  3131  42210.735811
# 33      4 -21.0  3356  42211.326076
# 34      4 -21.0  3784  42212.142889
# 35      4 -21.0  3131  42212.602635
# 36      4 -20.0  3554  42213.596390
# 37      4 -20.0  3367  42213.993111
# 38      4 -21.0  3243  42214.058298
# 39      4 -21.0  3656  42217.128606
# 40      5 -21.0  3168  42219.551344
# 41      5 -20.0  3350  42221.396540
# 42      5 -20.0  3367  42222.192115
# 43      5 -20.0  3834  42222.265087
# 44      5 -21.0  3536  42223.953279
# 45      5 -20.0  3610  42224.237703
# 46      5 -20.0  3832  42224.312461
# 47      5 -20.0  3479  42226.999746
# 48      6 -21.0  3304  42228.792103
# 49      6 -21.0  3168  42230.923118

# %%
video_folder = "logs/videos/"
video_length = 1000# Record the video

env = VecVideoRecorder(train_env_ppo, video_folder,
                       record_video_trigger=lambda x: x == 0, video_length=video_length,
                       name_prefix=f"trained-agent-{ENV_ID}")

# Reset the environment
obs = env.reset()

# Run the environment for the specified number of steps using the trained model
for _ in range(video_length + 1):
    action, _ = agent_ppo.predict(obs)  # Predict the action using the trained model
    obs, _, _, _ = env.step(action)  # Take the action in the environment

# Close the VecVideoRecorder and save the video
env.close()

# Function to display the video
def show_video(video_path):
    mp4 = open(video_path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML(f'<video width="480" height="320" controls><source src="{data_url}" type="video/mp4"></video>')

# Display the video
show_video(video_folder + f"trained-agent-{ENV_ID}-step-0-to-step-{video_length}.mp4")

# %% [markdown]
# # Analysis - direct comparison

# %%
agent_ppo = PPO.load(MODEL_PATH_PPO, env = train_env_ppo)
agent_a2c = A2C.load(MODEL_PATH_A2C, env = train_env_a2c)
agent_dqn = DQN.load(MODEL_PATH_DQN, env = train_env_dqn)

# Load the results from the log directory
results_ppo = load_results(LOG_DIR_PPO)
results_a2c = load_results(LOG_DIR_A2C)
results_dqn = load_results(LOG_DIR_DQN)

# Display the first 50 rows of the DataFrame
print(results_ppo.head(50))
print(results_a2c.head(50))
print(results_dqn.head(50))

# Plot rewards over episode index
plt.figure(figsize=(12, 6))
plt.plot(results_ppo.index, results_ppo['r'], label='PPO')
plt.plot(results_a2c.index, results_a2c['r'], label='A2C')
plt.plot(results_dqn.index, results_dqn['r'], label='DQN')
plt.xlabel('Episode')
plt.ylabel('Total Reward per Episode')
plt.legend()
plt.show()
# Out:
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
#     index     r     l             t
# 0       0 -21.0  3168  42170.635483
# 1       0 -20.0  3370  42171.172319
# 2       0 -21.0  3416  42171.372869
# 3       0 -20.0  3481  42171.497216
# 4       0 -20.0  3485  42171.515601
# 5       0 -21.0  3489  42171.548752
# 6       0 -20.0  3588  42171.845340
# 7       0 -19.0  3985  42173.036754
# 8       1 -21.0  3493  42181.794089
# 9       1 -19.0  4014  42182.283345
# 10      1 -20.0  3607  42182.355926
# 11      1 -20.0  3840  42182.834577
# 12      1 -20.0  3902  42182.917225
# 13      1 -20.0  3972  42183.255213
# 14      1 -20.0  4210  42183.511898
# 15      1 -20.0  3719  42183.888161
# 16      2 -21.0  3243  42191.294457
# 17      2 -21.0  3131  42191.677953
# 18      2 -20.0  3367  42192.260199
# 19      2 -20.0  3374  42192.664208
# 20      2 -21.0  3280  42193.185227
# 21      2 -20.0  3839  42193.934210
# 22      2 -20.0  3647  42194.574170
# 23      2 -20.0  3955  42194.791344
# 24      3 -19.0  3667  42201.524900
# 25      3 -20.0  3481  42202.074964
# 26      3 -21.0  3355  42202.165331
# 27      3 -18.0  4319  42203.719115
# 28      3 -21.0  3888  42203.944342
# 29      3 -19.0  3832  42204.704420
# 30      3 -21.0  3776  42205.069107
# 31      3 -20.0  4431  42206.949577
# 32      4 -21.0  3131  42210.735811
# 33      4 -21.0  3356  42211.326076
# 34      4 -21.0  3784  42212.142889
# 35      4 -21.0  3131  42212.602635
# 36      4 -20.0  3554  42213.596390
# 37      4 -20.0  3367  42213.993111
# 38      4 -21.0  3243  42214.058298
# 39      4 -21.0  3656  42217.128606
# 40      5 -21.0  3168  42219.551344
# 41      5 -20.0  3350  42221.396540
# 42      5 -20.0  3367  42222.192115
# 43      5 -20.0  3834  42222.265087
# 44      5 -21.0  3536  42223.953279
# 45      5 -20.0  3610  42224.237703
# 46      5 -20.0  3832  42224.312461
# 47      5 -20.0  3479  42226.999746
# 48      6 -21.0  3304  42228.792103
# 49      6 -21.0  3168  42230.923118
#     index     r     l          t
# 0       0 -21.0  3296  21.254553
# 1       0 -21.0  3300  21.286794
# 2       0 -20.0  3547  21.984628
# 3       0 -20.0  3607  22.178442
# 4       0 -21.0  3611  22.324825
# 5       0 -21.0  3658  22.458313
# 6       0 -20.0  4024  23.326391
# 7       0 -20.0  4242  23.987756
# 8       1 -21.0  3168  29.663404
# 9       1 -20.0  3591  30.954260
# 10      1 -20.0  3367  31.033541
# 11      1 -20.0  3348  31.183288
# 12      1 -21.0  3540  31.645898
# 13      1 -21.0  3286  32.089650
# 14      1 -21.0  3648  33.751044
# 15      1 -19.0  4238  33.793221
# 16      2 -21.0  3296  39.860815
# 17      2 -21.0  3286  39.958400
# 18      2 -20.0  4040  40.598095
# 19      2 -20.0  3783  41.101307
# 20      2 -20.0  3542  41.540833
# 21      2 -21.0  3876  42.042778
# 22      2 -21.0  3296  42.457860
# 23      2 -18.0  4877  46.746575
# 24      3 -21.0  3244  49.334467
# 25      3 -21.0  3544  49.420109
# 26      3 -20.0  3595  49.695423
# 27      3 -20.0  3350  50.154279
# 28      3 -21.0  3131  50.912544
# 29      3 -20.0  3370  51.123419
# 30      3 -20.0  3798  51.753999
# 31      3 -21.0  3595  56.239795
# 32      4 -21.0  3168  57.675676
# 33      4 -20.0  3462  58.596036
# 34      4 -20.0  3370  58.625675
# 35      4 -21.0  3296  58.814370
# 36      4 -21.0  3304  59.728523
# 37      4 -21.0  3296  59.886309
# 38      4 -20.0  3479  60.996930
# 39      5 -21.0  3168  66.042490
# 40      5 -21.0  3296  67.231655
# 41      5 -20.0  3485  67.821580
# 42      5 -21.0  3243  68.259230
# 43      4 -20.0  4663  68.696644
# 44      5 -21.0  3296  69.760479
# 45      5 -17.0  4659  71.493639
# 46      5 -20.0  4314  71.590889
# 47      6 -21.0  3408  75.475273
# 48      6 -21.0  3131  76.491719
# 49      6 -20.0  3592  77.178973
#     index     r     l             t
# 0       0 -21.0  3339  19849.590314
# 1       0 -21.0  3368  19849.708496
# 2       0 -20.0  3460  19849.897865
# 3       0 -20.0  3685  19850.455690
# 4       0 -20.0  3734  19850.553232
# 5       0 -21.0  3764  19850.625850
# 6       0 -21.0  3888  19850.894533
# 7       0 -19.0  4148  19851.507693
# 8       1 -21.0  3168  19857.006629
# 9       1 -21.0  3056  19857.405226
# 10      1 -21.0  3168  19857.747735
# 11      1 -21.0  3780  19858.152419
# 12      1 -21.0  3760  19858.208716
# 13      1 -21.0  3131  19858.581872
# 14      1 -20.0  3940  19859.414097
# 15      1 -21.0  3943  19859.810225
# 16      2 -20.0  3623  19865.622095
# 17      2 -20.0  3847  19865.774446
# 18      2 -20.0  3481  19866.092720
# 19      2 -21.0  3280  19866.842961
# 20      2 -21.0  3168  19866.970922
# 21      2 -19.0  4344  19867.676549
# 22      2 -19.0  4353  19868.098635
# 23      2 -18.0  4849  19869.627858
# 24      3 -21.0  3168  19874.165146
# 25      3 -19.0  3752  19874.329458
# 26      3 -20.0  3609  19874.346493
# 27      3 -21.0  3363  19874.539528
# 28      3 -19.0  4010  19874.839692
# 29      3 -20.0  3845  19876.878695
# 30      3 -18.0  4417  19877.712504
# 31      3 -20.0  4014  19878.740996
# 32      4 -21.0  3368  19881.798670
# 33      4 -21.0  3176  19882.008061
# 34      4 -20.0  3485  19882.404926
# 35      4 -20.0  4029  19883.519895
# 36      4 -21.0  3174  19884.141400
# 37      4 -18.0  4617  19884.912002
# 38      4 -21.0  3540  19886.847304
# 39      4 -19.0  4125  19887.114086
# 40      5 -21.0  3056  19889.404769
# 41      5 -21.0  3485  19889.798033
# 42      5 -21.0  3280  19890.984720
# 43      5 -19.0  4100  19891.407989
# 44      5 -21.0  3780  19893.435630
# 45      5 -21.0  4132  19893.530170
# 46      5 -21.0  3056  19894.047087
# 47      5 -21.0  3408  19894.569949
# 48      6 -20.0  3367  19897.488912
# 49      6 -19.0  3752  19898.007930

# %%
# Load the training results
def load_training_results(log_dir):
    results = load_results(log_dir)
    timesteps, rewards = ts2xy(results, 'timesteps')
    return timesteps, rewards

train_timesteps_ppo, train_rewards_ppo = load_training_results(LOG_DIR_PPO)
train_timesteps_a2c, train_rewards_a2c = load_training_results(LOG_DIR_A2C)
train_timesteps_dqn, train_rewards_dqn = load_training_results(LOG_DIR_DQN)

plt.figure(figsize=(12, 6))
plt.plot(train_timesteps_ppo, train_rewards_ppo, label='PPO')
plt.plot(train_timesteps_a2c, train_rewards_a2c, label='A2C')
plt.plot(train_timesteps_dqn, train_rewards_dqn, label='DQN')
plt.xlabel('Timesteps')
plt.ylabel('Training Reward')
plt.legend()
plt.title('Training Rewards over Timesteps')
plt.show()

# %%
# Load episode lengths from the log directory
def load_episode_lengths(log_dir):
    results = load_results(log_dir)
    episode_lengths = results['l']
    return episode_lengths

# Load episode lengths for PPO, A2C, and DQN
episode_lengths_ppo = load_episode_lengths(LOG_DIR_PPO)
episode_lengths_a2c = load_episode_lengths(LOG_DIR_A2C)
episode_lengths_dqn = load_episode_lengths(LOG_DIR_DQN)

# Plot episode lengths over episode index
plt.figure(figsize=(12, 6))
plt.plot(episode_lengths_ppo, label='PPO', color ='blue')
plt.plot(episode_lengths_a2c, label='A2C', color ='orange')
plt.plot(episode_lengths_dqn, label='DQN', color = 'green')
plt.xlabel('Episode')
plt.ylabel('Episode Length')
plt.legend()
plt.title('')
plt.show()
