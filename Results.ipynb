# %% [markdown]
# <a href="https://colab.research.google.com/github/hchaparov/Dynamic_Pricing_MARL/blob/main/Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Baselines

# %%
import matplotlib.pyplot as plt

# Data
agents = ['Negamax', 'Random']
win_rates = [0.98, 0.02]

# Create plot
fig, ax1 = plt.subplots(figsize=(7, 6))  # Adjust figsize if needed

# Plot win rates
bars1 = ax1.bar(agents, win_rates, color=['blue', 'orange'])
ax1.set_title('Win Rates of Agents')
ax1.set_xlabel('Baseline opponents', fontweight='bold')
ax1.set_ylabel('Win rate', fontweight='bold')
ax1.set_ylim(0, 1)  # Win rates are between 0 and 1
ax1.yaxis.grid(True)

# Add win rate percentages above bars
for bar in bars1:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval + 0.01, f'{yval:.0%}', ha='center', va='bottom')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2A_Connect4_PPO

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['PPO vs Random agent', 'PPO vs Negamax agent', 'PPO vs PPO agent']
agent1_win_percentages = [0.84, 0.06, 0.57]
agent2_win_percentages = [0.16, 0.94, 0.43]

x = np.arange(len(categories))  # the label locations
width = 0.35  # the width of the bars

# Plotting win percentages
fig, ax = plt.subplots(figsize=(10, 6))

rects1 = ax.bar(x - width/2, agent1_win_percentages, width, label='200 000-timestep PPO agent Win %', color='blue')
rects2 = ax.bar(x + width/2, agent2_win_percentages, width, label='Random/Negmax/PPO agent Win %', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Opponents', fontweight='bold')
ax.set_ylabel('Win rate', fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1)
ax.legend()

# Function to add labels on top of bars
def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.0%}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1, ax)
autolabel(rects2, ax)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['PPO vs Random agent', 'PPO vs Negamax agent', 'PPO vs PPO agent']
agent1_win_percentages = [0.8, 0.05, 0.51]
agent2_win_percentages = [0.2, 0.95, 0.49]

x = np.arange(len(categories))  # the label locations
width = 0.35  # the width of the bars

# Plotting win percentages
fig, ax = plt.subplots(figsize=(10, 6))

rects1 = ax.bar(x - width/2, agent1_win_percentages, width, label='100 000-timestep PPO agent Win %', color='blue')
rects2 = ax.bar(x + width/2, agent2_win_percentages, width, label='Random/Negmax/PPO agent Win %', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Opponents', fontweight='bold')
ax.set_ylabel('Win rate', fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1)
ax.legend()

# Function to add labels on top of bars
def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.0%}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1, ax)
autolabel(rects2, ax)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['PPO vs Random agent', 'PPO vs Negamax agent', 'PPO vs PPO agent']
agent1_win_percentages = [0.72, 0.01, 0.50]
agent2_win_percentages = [0.28, 0.99, 0.50]

x = np.arange(len(categories))  # the label locations
width = 0.35  # the width of the bars

# Plotting win percentages
fig, ax = plt.subplots(figsize=(10, 6))

rects1 = ax.bar(x - width/2, agent1_win_percentages, width, label='50 000-timestep PPO agent Win %', color='blue')
rects2 = ax.bar(x + width/2, agent2_win_percentages, width, label='Random/Negmax/PPO agent Win %', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Opponents', fontweight='bold')
ax.set_ylabel('Win rate', fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1)
ax.legend()

# Function to add labels on top of bars
def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.0%}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1, ax)
autolabel(rects2, ax)

fig.tight_layout()

plt.show()

# %% [markdown]
# # A2C

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['A2C vs Random agent', 'A2C vs Negamax agent', 'A2C vs A2C agent']
agent1_win_percentages = [0.94, 0.04, 0.49]
agent2_win_percentages = [0.06, 0.96, 0.51]

x = np.arange(len(categories))  # the label locations
width = 0.35  # the width of the bars

# Plotting win percentages
fig, ax = plt.subplots(figsize=(10, 6))

rects1 = ax.bar(x - width/2, agent1_win_percentages, width, label='200 000-timestep A2C agent Win %', color='blue')
rects2 = ax.bar(x + width/2, agent2_win_percentages, width, label='Random/Negmax/A2C agent Win %', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Opponents', fontweight='bold')
ax.set_ylabel('Win rate', fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1)
ax.legend()

# Function to add labels on top of bars
def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.0%}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1, ax)
autolabel(rects2, ax)

fig.tight_layout()

plt.show()

# %% [markdown]
# # DQN

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['DQN vs Random agent', 'DQN vs Negamax agent', 'DQN vs DQN agent']
agent1_win_percentages = [0.82, 0.02, 0.53]
agent2_win_percentages = [0.18, 0.98, 0.47]

x = np.arange(len(categories))  # the label locations
width = 0.35  # the width of the bars

# Plotting win percentages
fig, ax = plt.subplots(figsize=(10, 6))

rects1 = ax.bar(x - width/2, agent1_win_percentages, width, label='200 000-timestep DQN agent Win %', color='blue')
rects2 = ax.bar(x + width/2, agent2_win_percentages, width, label='Random/Negmax/DQN agent Win %', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Opponents', fontweight='bold')
ax.set_ylabel('Win rate', fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1)
ax.legend()

# Function to add labels on top of bars
def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.0%}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1, ax)
autolabel(rects2, ax)

fig.tight_layout()

plt.show()

# %% [markdown]
# # Direct clash

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['PPO vs DQN', 'PPO vs A2C', 'A2C vs DQN']
agent1_win_percentages = [0.5, 0.34, 0.52]
agent2_win_percentages = [0.5, 0.66, 0.48]

x = np.arange(len(categories))  # the label locations
width = 0.35  # the width of the bars

# Plotting win percentages
fig, ax = plt.subplots(figsize=(10, 6))

rects1 = []
rects2 = []

# Create bars for each category with appropriate colors
for i, category in enumerate(categories):
    if category == 'PPO vs DQN':
        rect1 = ax.bar(x[i] - width/2, agent1_win_percentages[i], width, label='200 000-timestep PPO agent Win %', color='blue')
        rect2 = ax.bar(x[i] + width/2, agent2_win_percentages[i], width, label='200 000-timestep DQN agent Win %', color='green')
    elif category == 'PPO vs A2C':
        rect1 = ax.bar(x[i] - width/2, agent1_win_percentages[i], width, label='200 000-timestep PPO agent Win %', color='blue')
        rect2 = ax.bar(x[i] + width/2, agent2_win_percentages[i], width, label='200 000-timestep A2C agent Win %', color='orange')
    elif category == 'A2C vs DQN':
        rect1 = ax.bar(x[i] - width/2, agent1_win_percentages[i], width, label='200 000-timestep A2C agent Win %', color='orange')
        rect2 = ax.bar(x[i] + width/2, agent2_win_percentages[i], width, label='200 000-timestep DQN agent Win %', color='green')
    rects1.append(rect1)
    rects2.append(rect2)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Opponents', fontweight='bold')
ax.set_ylabel('Win rate', fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1)

# Only show one set of legend entries
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
ax.legend(by_label.values(), by_label.keys())

# Function to add labels on top of bars
def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect_group in rects:
        for rect in rect_group:
            height = rect.get_height()
            ax.annotate(f'{height:.0%}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')

autolabel(rects1, ax)
autolabel(rects2, ax)

fig.tight_layout()

plt.show()

# %% [markdown]
# # MCTS

# %%
import matplotlib.pyplot as plt

# Data
strategies = ['MCTS vs Random', 'MCTS vs Negamax']
win_rates = [100, 98]
draw_rates = [0, 2]
loss_rates = [0, 0]  # Assuming 0% loss rates since it's not mentioned

# Bar width
bar_width = 0.25

# Bar positions
r1 = range(len(strategies))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Create bar plot
bars1 = plt.bar(r1, win_rates, color='b', width=bar_width, edgecolor='grey', label='Win Rate of\n MCTS agent')
bars2 = plt.bar(r2, draw_rates, color='g', width=bar_width, edgecolor='grey', label='Draw Rate of\n MCTS agent')
bars3 = plt.bar(r3, loss_rates, color='orange', width=bar_width, edgecolor='grey', label='Loss Rate of\n MCTS agent')

# Add labels
plt.xlabel('Opponents', fontweight='bold')
plt.ylabel('Percentage', fontweight='bold')
plt.xticks([r + bar_width for r in range(len(strategies))], strategies)
plt.title('')

# Add percentage text on bars
for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval}%', ha='center', va='bottom')

for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval}%', ha='center', va='bottom')

for bar in bars3:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval}%', ha='center', va='bottom')

# Add legend
plt.legend()

# Show plot
plt.show()
